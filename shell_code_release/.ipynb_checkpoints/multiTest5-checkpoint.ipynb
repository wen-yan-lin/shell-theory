# %%
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras import backend as K
import numpy as np

import dirUtil 
from highDimLearning import vgg2feat

import tensorflow as tf

from sklearn.metrics.pairwise import euclidean_distances

import matplotlib.pyplot as plt




    

def feat2labels(feat):
    numClass = len(feat)
    numDim = feat[0].shape[1]
    numPts = 0
    for i in range(numClass):
        numPts = numPts + feat[i].shape[0]

    allFeat = np.zeros([numPts, numDim])
    allLabels = np.zeros(numPts, dtype = int)
    cur = 0
    for i in range(numClass):
        allFeat[cur:cur+feat[i].shape[0],:] = feat[i]
        allLabels[cur:cur+feat[i].shape[0]] = i
        cur = cur + feat[i].shape[0]
    return allFeat, allLabels
        
    


trainingNum = 1000

tf.reset_default_graph()
K.clear_session()
folder = '/home/sliu/code/keras-tutorial/animals/dogs/'
feats = dirUtil.dir2vgg16(folder)
feat1 = vgg2feat(feats)


folder2 = '/home/sliu/code/keras-tutorial/animals/cats/'
tf.reset_default_graph()
K.clear_session()
feats = dirUtil.dir2vgg16(folder2)
feat2 = vgg2feat(feats)

folder3 = '/home/sliu/code/keras-tutorial/animals/panda/'
tf.reset_default_graph()
K.clear_session()
feats = dirUtil.dir2vgg16(folder3)
feat3 = vgg2feat(feats)

allFeat, gt = feat2labels([feat1, feat2, feat3])
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# W0727 07:29:18.935418 140004186875712 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0727 07:29:18.936503 140004186875712 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0727 07:29:18.952572 140004186875712 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0727 07:29:18.953603 140004186875712 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0727 07:29:18.955620 140004186875712 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0727 07:29:18.977921 140004186875712 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
import numpy as np
import tensorflow as tf
import copy

from sklearn.cluster import KMeans


def multiModelA(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    dist_ = tf.math.pow(projDist_-Sig_, 2)

    
    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/advCost
    selfCost = tf.reduce_sum(selfCost)/numFeat_
    
    dCost = tf.reduce_sum(tf.math.pow(advCost - tf.reduce_mean(advCost),2))/numFeat_

    final_cost = selfCost + lambda_*regularizer_ +dCost


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)

        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig
        

def multiModel2A(feat,  meanEst, sigEst, initMask, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")

    
    mask = tf.placeholder("float", feat.shape[0])
    numInMask = tf.placeholder("float", shape=())


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

   
    dist_ = tf.math.pow(projDist_-Sig_, 2)
   

    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/advCost
    selfCost = mask*selfCost
    selfCost = tf.reduce_sum(selfCost)/numInMask
    
    dCost = tf.reduce_sum(tf.math.pow(advCost - tf.reduce_mean(advCost),2))/numFeat_

    final_cost = selfCost + lambda_*regularizer_ + dCost

   

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        curMask = copy.deepcopy(initMask)
        curNum = sum(curMask)
        for i in range(5001):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})
            a = sess.run(advCost, feed_dict={mask: curMask, numInMask: curNum})
            if i%100 == 0 and i >0:
                W = sess.run(W_)
                Sig = sess.run(Sig_)
                c = np.matmul(feat,W) -Sig
                d = np.absolute(c)                
                ns = np.min(d,axis=1)/np.max(d, axis =1)
                thres = np.percentile(ns,50+ i/100.0)
                curMask = ns<thres
                curNum = np.sum(curMask)
                print(i,thres)



        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig
        



def clusterData(allFeat, numClass=2):

    tf.reset_default_graph()
    
    #    k-means initilization
    kmeans = KMeans(n_clusters=numClass, random_state=0).fit(allFeat)
    means = kmeans.cluster_centers_
    means = means/np.linalg.norm(means, axis =1, keepdims=True)
    sigInit = np.zeros([numClass])
    labelK = kmeans.predict(allFeat)
    for i in range(numClass):
        mask = labelK == i
        sigInit[i] = np.mean(np.matmul(allFeat, np.transpose(means)))
    
    W = copy.deepcopy(np.transpose(means))
    Sig = copy.deepcopy(np.transpose(sigInit))
        
    score = np.min(kmeans.transform(allFeat), axis =1)
    val = np.percentile(score, 50)
    maskK = score<val


    W, Sig = multiModelA(allFeat[maskK,:], W, Sig,
                        weight=1.0, numIter=10000)
    tf.reset_default_graph()
    W, Sig = multiModel2A(allFeat, W, Sig, maskK, weight=1.0, numIter=10000)
    
    tf.reset_default_graph()
    W, Sig = multiModelA(allFeat, W, Sig,
                      weight=1.0, numIter=10000)

    c = np.matmul(allFeat,W) -Sig
    label = np.argmax(c, axis =1)
    return W, Sig, label, c, labelK

# %%
from sklearn.cluster import KMeans
import copy

test, gtTest = feat2labels([feat1, feat2])
numClass = 2
kmeans = KMeans(n_clusters=numClass, random_state=0).fit(test)
means = kmeans.cluster_centers_
means = means/np.linalg.norm(means, axis =1, keepdims=True)
sigInit = np.zeros([numClass])
labelK = kmeans.predict(test)
for i in range(numClass):
    mask = labelK == i
    sigInit[i] = np.mean(np.matmul(test[mask,:], np.transpose(means)))

# %%
def multiModelA(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    Sig_adv = tf.get_variable("Sa", dtype=tf.float32,
                            initializer=sigEst.astype("float32"))

    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    dist_ = tf.math.pow(projDist_-Sig_, 2)

    
    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/advCost
    selfCost = tf.reduce_sum(selfCost)/numFeat_
    
    dist_X = tf.reduce_max(dist_, axis=1, keepdims=True)
    dist_2 = tf.math.pow(dist_X-Sig_adv, 2)
    dCost = tf.reduce_min(dist_2, axis =1)
    dCost = tf.reduce_sum(dCost)/numFeat_
    
    final_cost = selfCost + lambda_*regularizer_ +100.0*dCost


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)
                t = sess.run(dist_X)
                s = sess.run(dist_X)
                print(t[:10,:])


        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig

# %%
def multiModelB(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    Sig_adv = tf.get_variable("Sa", dtype=tf.float32,
                            initializer=sigEst.astype("float32"))

    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    
    projDiff = projDist_-Sig_
    
    
    dist_ = tf.math.pow(projDiff, 2)

    
    advCost = tf.reduce_max(projDiff, axis=1)
    advCost = tf.math.pow(advCost, 2)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/advCost
    selfCost = tf.reduce_sum(selfCost)/numFeat_
    
    dist_X = tf.reduce_max(projDiff, axis=1, keepdims=True)
    dist_2 = tf.math.pow(dist_X- Sig_ -Sig_adv, 2)
    dCost = tf.reduce_min(dist_2, axis =1)
    dCost = tf.reduce_sum(dCost)/numFeat_
    
    final_cost = selfCost + lambda_*regularizer_ + 10*dCost


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)
                t = sess.run(dist_2)
                s = sess.run(dCost)
                print(s)
                print(t.shape)
                #print(t[:10,:])


        W = sess.run(W_)
        Sig = sess.run(Sig_)
        SigAdv = sess.run(Sig_adv)
    return W, Sig, SigAdv

# %%
tf.reset_default_graph()

W = copy.deepcopy(np.transpose(means))
Sig = copy.deepcopy(np.transpose(sigInit))
score = np.min(kmeans.transform(test), axis =1)
val = np.percentile(score, 50)
maskK = score<val


W, Sig, SigAdv = multiModelB(test[maskK,:],  W, Sig, weight=0.0, numIter=10000)
c = np.matmul(test,W) -Sig
label = np.argmax(c, axis =1)


plt.figure()
plt.scatter(c[maskK, 0],
            c[maskK, 1],
            c=gtTest[maskK], alpha=0.1)
plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
             c=gtTest, alpha=0.1)

print(np.sum(np.absolute(label-gtTest)))
# Out:
# 0 289.2964
# 2.8899982
# (1000, 2)
# 500 nan
# nan
# (1000, 2)
# 1000 nan
# nan
# (1000, 2)
# 1500 nan
# nan
# (1000, 2)
# 2000 nan
# nan
# (1000, 2)
# 2500 nan
# nan
# (1000, 2)
# 3000 nan
# nan
# (1000, 2)
# 3500 nan
# nan
# (1000, 2)
# 4000 nan
# nan
# (1000, 2)
# 4500 nan
# nan
# (1000, 2)
# 5000 nan
# nan
# (1000, 2)
# 5500 nan
# nan
# (1000, 2)

# %%
c = np.matmul(allFeat,W) -Sig


plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
            c=gt, alpha=0.1)

# %%
W, Sig, lab, c, labelK = clusterData(allFeat, numClass=3)


plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
            c=gt, alpha=0.1)
plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
             c=lab, alpha=0.1)

print(np.sum(np.absolute(lab-gt)))
print(np.sum(np.absolute(labelK-gt)))
# Out:
# 0 0.124412104
# 500 0.023948373
# 1000 0.015929742
# 1500 0.011925366
# 2000 0.009371886
# 2500 0.007579895
# 3000 0.0062608393
# 3500 0.005260529
# 4000 0.0044845548
# 4500 0.0038709233
# 5000 0.0033774527
# 5500 0.0029747128
# 6000 0.0026417451
# 6500 0.002363287
# 7000 0.0021280295
# 7500 0.0019274282
# 8000 0.0017549398
# 8500 0.0016054816
# 9000 0.001475061
# 9500 0.0013605106
# 100 0.021074733710565067
# 200 0.02121496820748974
# 300 0.022632934567527185
# 400 0.02452974140790092
# 500 0.025158020909729614
# 600 0.026671024848286935
# 700 0.027235191889439972
# 800 0.02889967235951891
# 900 0.03028747389226734
# 1000 0.030670742703629905
# 1100 0.03222360940860968
# 1200 0.03316816314998101
# 1300 0.03563176212561743
# 1400 0.038196174805892893
# 1500 0.03969621443828275
# 1600 0.04295503147500236
# 1700 0.04591990053189707
# 1800 0.04952506264516231
# 1900 0.05175901435813254
# 2000 0.05526662832082736
# 2100 0.05846594941818496
# 2200 0.06439219337727332
# 2300 0.07100001862684213
# 2400 0.07466815258701076
# 2500 0.07991438203129916
# 2600 0.08409234971452345
# 2700 0.08891655838951078
# 2800 0.0947490677461316
# 2900 0.09987531285972237
# 3000 0.10458927640033182
# 3100 0.10866979338684016
# 3200 0.11255434522025035
# 3300 0.11763810131696147
# 3400 0.12486460042775646
# 3500 0.13219180189432406
# 3600 0.1421014286723132
# 3700 0.14866040128542313
# 3800 0.14993444859126903
# 3900 0.1596246306929802
# 4000 0.17374390900488446
# 4100 0.18272444015426154
# 4200 0.18789905603326398
# 4300 0.19965070136206084
# 4400 0.2235223776499108
# 4500 0.25612125961483234
# 4600 0.27907421889156825
# 4700 0.32851162059708383
# 4800 0.3869270954074049
# 4900 0.5145377773612744
# 5000 0.9485168362891923
# 0 0.025217893
# 500 0.0077478285
# 1000 0.016117921
# 1500 0.003672081
# 2000 0.0030436728
# 2500 0.002601258
# 3000 0.0023524242
# 3500 0.0019329049
# 4000 0.0017414712
# 4500 0.0016098168
# 5000 0.0014920217
# 5500 0.0019013137
# 6000 0.0026456097
# 6500 0.0025764224
# 7000 0.002475324
# 7500 0.002383195
# 8000 0.0022995512
# 8500 0.0022231208
# 9000 0.0021528858
# 9500 0.0020881814
# 3840
# 3905

# %%
c = np.matmul(allFeat,W) -Sig
lab = np.argmax(c, axis =1)
plt.scatter(c[:, 2],
            c[:, 1],
             c=gt, alpha=0.1)
plt.colorbar()
plt.figure()
plt.scatter(c[:, 2],
            c[:, 1],
             c=lab, alpha=0.1)
plt.colorbar()


print(np.sum(np.absolute(lab-gt)))
# Out:
# 3783

# %%
import umap

embed = umap.UMAP().fit(allFeat)
f = embed.transform(allFeat)
plt.scatter(f[:, 0],
            f[:, 1],
             c=gt, alpha=0.1)
kmeans = KMeans(n_clusters=3, random_state=0).fit(f)
labelF = kmeans.predict(f)
# Out:
# /home/daniel/.local/lib/python3.6/site-packages/umap/umap_.py:349: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "fuzzy_simplicial_set" failed type inference due to: Untyped global name 'nearest_neighbors': cannot determine Numba type of <class 'function'>
#
# File "../../../../../home/daniel/.local/lib/python3.6/site-packages/umap/umap_.py", line 467:
# def fuzzy_simplicial_set(
#     <source elided>
#     if knn_indices is None or knn_dists is None:
#         knn_indices, knn_dists, _ = nearest_neighbors(
#         ^
#
#   @numba.jit()
# /home/daniel/.local/lib/python3.6/site-packages/numba/compiler.py:725: NumbaWarning: Function "fuzzy_simplicial_set" was compiled in object mode without forceobj=True.
#
# File "../../../../../home/daniel/.local/lib/python3.6/site-packages/umap/umap_.py", line 350:
# @numba.jit()
# def fuzzy_simplicial_set(
# ^
#
#   self.func_ir.loc))
# /home/daniel/.local/lib/python3.6/site-packages/numba/compiler.py:734: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../../../home/daniel/.local/lib/python3.6/site-packages/umap/umap_.py", line 350:
# @numba.jit()
# def fuzzy_simplicial_set(
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, self.func_ir.loc))

# %%
def clusteringScore(lab, gt):
    numClus = np.max(gt)+1
    scores = np.zeros(numClus)
    for i in range(numClus):
        mask = gt == i
        for j in range(numClus):
            trialMask = lab == j
            s = np.sum(trialMask==mask)
            if s > scores[i]:
                scores[i] = s
    return scores
            
print(clusteringScore(lab, gt))
print(clusteringScore(labelK, gt))
print(clusteringScore(labelF, gt))
# Out:
# [2896. 2918. 2916.]
# [2763. 2822. 2927.]
# [2929. 2930. 2965.]

# %%
def multiModelX(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    dist_ = tf.math.pow(projDist_-Sig_, 2)
    
    top2 = tf.math.top_k(-dist_, 3).values
    dCost = top2[:,0]/top2[:,1]
    selfCost = tf.reduce_sum(dCost)/numFeat_

    final_cost = selfCost + lambda_*regularizer_


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)            
            #a = sess.run(dCost)
            #print(a.shape)
            #print(a[:10])
            #k = donk
            if i%500 == 0:               
                d = sess.run(final_cost)
                print(i, d)

        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig

# %%
from sklearn.cluster import KMeans

numClass = 3
kmeans = KMeans(n_clusters=numClass, random_state=0).fit(allFeat)
means = kmeans.cluster_centers_

means = means/np.linalg.norm(means, axis =1, keepdims=True)
sigInit = np.zeros([numClass])
labels = kmeans.predict(allFeat)
for i in range(numClass):
    mask = labels == i
    sigInit[i] = np.mean(np.matmul(allFeat, np.transpose(means)))


score = np.min(kmeans.transform(allFeat), axis =1)
val = np.percentile(score, 50)
maskK = score<val

    
c = np.matmul(allFeat, np.transpose(means)) - sigInit
plt.scatter(c[:feat1.shape[0], 0],
            c[:feat1.shape[0], 1],
            color='red', alpha=0.1)
plt.scatter(c[feat1.shape[0]:, 0],
            c[feat1.shape[0]:, 1],
            color='blue', alpha=0.1)
plt.show();

# %%
tf.reset_default_graph()

WIni = copy.deepcopy(np.transpose(means))
SigIni = copy.deepcopy(np.transpose(sigInit))


WW, SigS = multiModelX(allFeat[maskK,:], WIni, SigIni, numIter= 100000)
# Out:
# 0 0.19762689
# 500 0.0148220165
# 1000 0.0057787984
# 1500 0.0028814129
# 2000 0.0016607968
# 2500 0.0010551005
# 3000 0.00072035176
# 3500 0.0005180621
# 4000 0.00038896865
# 4500 0.00030171374
# 5000 0.0002405409
# 5500 0.0001958856
# 6000 0.00016245649
# 6500 0.00013658006
# 7000 0.00011612658
# 7500 9.981035e-05
# 8000 8.649755e-05
# 8500 7.544778e-05
# 9000 6.619866e-05
# 9500 5.8337697e-05
# 10000 5.1798364e-05
# 10500 4.6129153e-05
# 11000 4.1196126e-05
# 11500 3.6868652e-05
# 12000 3.3189266e-05
# 12500 2.9904624e-05
# 13000 2.7045338e-05
# 13500 2.453232e-05
# 14000 2.2256569e-05
# 14500 2.0303803e-05
# 15000 1.8552779e-05
# 15500 1.6850776e-05
# 16000 1.5607442e-05
# 16500 1.4096329e-05
# 17000 1.3148627e-05
# 17500 1.1950908e-05
# 18000 1.1054819e-05
# 18500 1.0229592e-05
# 19000 9.40007e-06
# 19500 8.6998325e-06
# 20000 8.130323e-06
# 20500 7.450229e-06
# 21000 6.940802e-06
# 21500 6.4233936e-06
# 22000 5.9824015e-06
# 22500 5.572289e-06
# 23000 5.210065e-06
# 23500 4.777293e-06
# 24000 4.526193e-06
# 24500 4.232711e-06
# 25000 3.9661463e-06
# 25500 3.6561657e-06
# 26000 3.4571717e-06
# 26500 3.2636008e-06
# 27000 2.9627793e-06
# 27500 2.7518001e-06
# 28000 2.6725409e-06
# 28500 2.588391e-06
# 29000 2.4092406e-06
# 29500 2.190753e-06
# 30000 2.013183e-06
# 30500 1.918264e-06
# 31000 1.8950459e-06
# 31500 1.806319e-06
# 32000 1.6376351e-06
# 32500 1.47718e-06
# 33000 1.4290987e-06
# 33500 1.4091802e-06
# 34000 1.4048212e-06
# 34500 1.2533699e-06
# 35000 1.1309562e-06
# 35500 1.0569316e-06
# 36000 1.008235e-06
# 36500 9.559308e-07
# 37000 8.966387e-07
# 37500 8.5069547e-07
# 38000 8.1007533e-07
# 38500 7.702828e-07
# 39000 7.3591394e-07
# 39500 6.834207e-07
# 40000 6.251803e-07
# 40500 5.926721e-07
# 41000 5.446864e-07
# 41500 5.1802823e-07
# 42000 5.018785e-07
# 42500 5.127228e-07
# 43000 6.245334e-07
# 43500 5.6857044e-07
# 44000 4.593207e-07
# 44500 4.648396e-07
# 45000 4.303372e-07
# 45500 3.7204762e-07
# 46000 3.1053918e-07
# 46500 2.933035e-07
# 47000 2.749803e-07
# 47500 2.5383787e-07
# 48000 2.411232e-07
# 48500 2.4586188e-07
# 49000 3.5539932e-07
# 49500 5.556084e-07
# 50000 3.0389268e-07
# 50500 1.9917398e-07
# 51000 1.7760681e-07
# 51500 1.6548206e-07
# 52000 1.5791436e-07
# 52500 1.5174149e-07
# 53000 1.4478414e-07
# 53500 1.3796485e-07
# 54000 1.3124325e-07
# 54500 1.2681379e-07
# 55000 1.2623785e-07
# 55500 1.2892248e-07
# 56000 1.3101238e-07
# 56500 1.2820365e-07
# 57000 1.5067924e-07
# 57500 1.8708533e-07
# 58000 1.9427472e-07
# 58500 1.6126539e-07
# 59000 1.2282595e-07
# 59500 1.084218e-07
# 60000 1.03410535e-07
# 60500 9.984799e-08
# 61000 1.021441e-07
# 61500 9.4499875e-08
# 62000 8.013061e-08
# 62500 7.312295e-08
# 63000 6.7259464e-08
# 63500 6.243892e-08
# 64000 6.01343e-08
# 64500 5.6119664e-08
# 65000 4.9821207e-08
# 65500 4.546896e-08
# 66000 4.3557147e-08
# 66500 4.1743622e-08
# 67000 3.9025426e-08
# 67500 3.6153917e-08
# 68000 3.458408e-08
# 68500 3.3091677e-08
# 69000 3.1679843e-08
# 69500 3.0399846e-08
# 70000 2.9297858e-08
# 70500 2.8401967e-08
# 71000 2.770497e-08
# 71500 2.7195023e-08
# 72000 2.6133852e-08
# 72500 2.6070827e-08
# 73000 2.54388e-08
# 73500 2.5235884e-08
# 74000 2.6556886e-08
# 74500 2.8100024e-08
# 75000 6.2089896e-08
# 75500 1.8767294e-07
# 76000 2.0188442e-07
# 76500 8.461698e-08
# 77000 3.4955075e-08
# 77500 1.9437019e-08
# 78000 1.7498037e-08
# 78500 1.6914118e-08
# 79000 1.5230512e-08
# 79500 1.4700005e-08
# 80000 1.390026e-08
# 80500 1.3000117e-08
# 81000 1.2673343e-08
# 81500 1.2080949e-08
# 82000 1.1733822e-08
# 82500 1.1410102e-08
# 83000 1.0973459e-08
# 83500 1.0601617e-08
# 84000 1.0110163e-08
# 84500 1.057177e-08
# 85000 1.1049213e-08
# 85500 1.0485803e-08
# 86000 1.0079447e-08
# 86500 9.795908e-09
# 87000 9.526444e-09
# 87500 9.268686e-09
# 88000 9.016291e-09
# 88500 8.591741e-09
# 89000 8.115207e-09
# 89500 7.898756e-09
# 90000 7.686499e-09
# 90500 7.49047e-09
# 91000 7.3021087e-09
# 91500 7.119387e-09
# 92000 6.939858e-09
# 92500 6.7790946e-09
# 93000 6.6215105e-09
# 93500 6.504389e-09
# 94000 6.364898e-09
# 94500 6.494054e-09
# 95000 6.396916e-09
# 95500 6.2819416e-09
# 96000 6.1552496e-09
# 96500 5.976278e-09
# 97000 6.1513847e-09
# 97500 6.457627e-09
# 98000 6.349213e-09
# 98500 6.2366596e-09
# 99000 6.14041e-09
# 99500 6.0414584e-09

# %%
c = np.matmul(allFeat,WW) -SigS

# %%
plt.scatter(c[maskK, 0],
            c[maskK, 1],
             c=gt[maskK], alpha=0.1)
plt.figure()

plt.scatter(c[maskK, 1],
            c[maskK, 2],
             c=gt[maskK], alpha=0.1)

plt.figure()

plt.scatter(c[maskK, 0],
            c[maskK, 2],
             c=gt[maskK], alpha=0.1)
plt.colorbar()
