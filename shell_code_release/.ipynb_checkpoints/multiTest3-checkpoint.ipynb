# %%
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras import backend as K
import numpy as np

import dirUtil 
from highDimLearning import vgg2feat

import tensorflow as tf

from sklearn.metrics.pairwise import euclidean_distances

import matplotlib.pyplot as plt



def label(feat, w, sig):

    numClass = len(w)
    score = np.zeros([feat.shape[0], numClass])
    for i in range(numClass):
        ww = w[i]
        ww = np.reshape(ww, [ww.size, 1])
        sigg = np.reshape(sig[i], [sig[i].size, 1])
        score[:, i:i+1] = np.matmul(feat, ww)-sigg
    score = np.absolute(score)
    labels = np.argmin(score, axis=1)
    return labels, score

    

def feat2labels(feat):
    numClass = len(feat)
    numDim = feat[0].shape[1]
    numPts = 0
    for i in range(numClass):
        numPts = numPts + feat[i].shape[0]

    allFeat = np.zeros([numPts, numDim])
    allLabels = np.zeros(numPts, dtype = int)
    cur = 0
    for i in range(numClass):
        allFeat[cur:cur+feat[i].shape[0],:] = feat[i]
        allLabels[cur:cur+feat[i].shape[0]] = i
        cur = cur + feat[i].shape[0]
    return allFeat, allLabels
        
    


trainingNum = 1000

tf.reset_default_graph()
K.clear_session()
folder = '/media/daniel/D/code/keras-tutorial/animals/dogs/'
feats = dirUtil.dir2vgg16(folder)
feat1 = vgg2feat(feats)


folder2 = '/media/daniel/D/code/keras-tutorial/animals/cats/'
tf.reset_default_graph()
K.clear_session()
feats = dirUtil.dir2vgg16(folder2)
feat2 = vgg2feat(feats)

folder3 = '/media/daniel/D/code/keras-tutorial/animals/panda/'
tf.reset_default_graph()
K.clear_session()
feats = dirUtil.dir2vgg16(folder3)
feat3 = vgg2feat(feats)

allFeat, gt = feat2labels([feat1, feat2, feat3])

# %%
def multiModel(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    dist_ = tf.math.pow(projDist_-Sig_, 2)

    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_min(dist_, axis=1)
    selfCost = selfCost/advCost
    selfCost = tf.reduce_sum(selfCost)/numFeat_

    final_cost = selfCost + lambda_*regularizer_


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)

        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig
        

def multiModel2(feat,  meanEst, sigEst, initMask, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")

    
    mask = tf.placeholder("float", feat.shape[0])
    numInMask = tf.placeholder("float", shape=())


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

   
    dist_ = tf.math.pow(projDist_-Sig_, 2)
   

    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_min(dist_, axis=1)
    selfCost = selfCost/advCost
    selfCost = mask*selfCost
    selfCost = tf.reduce_sum(selfCost)/numInMask

    final_cost = selfCost + lambda_*regularizer_

   

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        curMask = copy.deepcopy(initMask)
        curNum = sum(curMask)
        for i in range(5001):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})
            a = sess.run(advCost, feed_dict={mask: curMask, numInMask: curNum})
            if i%100 == 0 and i >0:
                W = sess.run(W_)
                Sig = sess.run(Sig_)
                c = np.matmul(allFeat,W) -Sig
                d = np.absolute(c)                
                ns = np.min(d,axis=1)/np.max(d, axis =1)
                thres = np.percentile(ns,50+ i/100.0)
                curMask = ns<thres
                curNum = np.sum(curMask)
                print(i,thres)



        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig

# %%
def multiModelA(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    dist_ = tf.math.pow(projDist_-Sig_, 2)

    
    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/advCost
    selfCost = tf.reduce_sum(selfCost)/numFeat_

    final_cost = selfCost + lambda_*regularizer_


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)

        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig
        

def multiModel2A(feat,  meanEst, sigEst, initMask, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")

    
    mask = tf.placeholder("float", feat.shape[0])
    numInMask = tf.placeholder("float", shape=())


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

   
    dist_ = tf.math.pow(projDist_-Sig_, 2)
   

    advCost = tf.reduce_max(dist_, axis=1)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/advCost
    selfCost = mask*selfCost
    selfCost = tf.reduce_sum(selfCost)/numInMask

    final_cost = selfCost + lambda_*regularizer_

   

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        curMask = copy.deepcopy(initMask)
        curNum = sum(curMask)
        for i in range(5001):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})
            a = sess.run(advCost, feed_dict={mask: curMask, numInMask: curNum})
            if i%100 == 0 and i >0:
                W = sess.run(W_)
                Sig = sess.run(Sig_)
                c = np.matmul(allFeat,W) -Sig
                d = np.absolute(c)                
                ns = np.min(d,axis=1)/np.max(d, axis =1)
                thres = np.percentile(ns,50+ i/100.0)
                curMask = ns<thres
                curNum = np.sum(curMask)
                print(i,thres)



        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig

# %%
from sklearn.cluster import KMeans
import copy



def clusterData(allFeat, numClass=2):

    tf.reset_default_graph()
    
    #    k-means initilization
    kmeans = KMeans(n_clusters=numClass, random_state=0).fit(allFeat)
    means = kmeans.cluster_centers_
    means = means/np.linalg.norm(means, axis =1, keepdims=True)
    sigInit = np.zeros([numClass])
    labelK = kmeans.predict(allFeat)
    for i in range(numClass):
        mask = labelK == i
        sigInit[i] = np.mean(np.matmul(allFeat, np.transpose(means)))
    
    W = copy.deepcopy(np.transpose(means))
    Sig = copy.deepcopy(np.transpose(sigInit))
        
    score = np.min(kmeans.transform(allFeat), axis =1)
    val = np.percentile(score, 50)
    maskK = score<val


    W, Sig = multiModelA(allFeat[maskK,:], W, Sig,
                        weight=1.0, numIter=10000)
    tf.reset_default_graph()
    W, Sig = multiModel2A(allFeat, W, Sig, maskK, weight=1.0, numIter=10000)
    
    tf.reset_default_graph()
    W, Sig = multiModelA(allFeat, W, Sig,
                      weight=1.0, numIter=10000)

    c = np.matmul(allFeat,W) -Sig
    label = np.argmin(c, axis =1)
    return W, Sig, label, c, labelK

# %%
W, Sig, lab, c, labelK = clusterData(allFeat, numClass=3)



plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
            c=gt, alpha=0.1)
plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
             c=lab, alpha=0.1)

print(np.sum(np.absolute(lab-gt)))
print(np.sum(np.absolute(labelK-gt)))
# Out:
# 0 0.12325481
# 500 0.022629403
# 1000 0.014681737
# 1500 0.01076809
# 2000 0.008310552
# 2500 0.006609033
# 3000 0.0053704935
# 3500 0.004440198
# 4000 0.003724874
# 4500 0.003164051
# 5000 0.0027168777
# 5500 0.0023550128
# 6000 0.002058352
# 6500 0.0018123429
# 7000 0.0016062467
# 7500 0.0014320018
# 8000 0.0012834631
# 8500 0.0011558762
# 9000 0.00104552
# 9500 0.0009494538
# 100 0.020716460382329167
# 200 0.022123676272952475
# 300 0.023381194108563326
# 400 0.023822617728652636
# 500 0.025139716843776114
# 600 0.026924610329815114
# 700 0.0280007936045715
# 800 0.029361675846551995
# 900 0.03031246841195251
# 1000 0.03189374192569761
# 1100 0.03465878534687055
# 1200 0.03654487644152023
# 1300 0.03788812709985903
# 1400 0.04004342469277086
# 1500 0.042348924031885914
# 1600 0.04385062002209916
# 1700 0.04768293285057154
# 1800 0.05049763239029702
# 1900 0.0524675323196227
# 2000 0.0546625837336476
# 2100 0.0563276402946831
# 2200 0.05922592933806082
# 2300 0.06391782575490905
# 2400 0.0662810621812261
# 2500 0.06872190423049562
# 2600 0.07426490426753825
# 2700 0.07983036022779083
# 2800 0.08665635345093896
# 2900 0.0921615685379791
# 3000 0.0955618139074094
# 3100 0.10018969711140487
# 3200 0.10375032889357007
# 3300 0.11021087105261777
# 3400 0.1224350190360731
# 3500 0.12549095589768472
# 3600 0.13140138501475573
# 3700 0.14082380252398857
# 3800 0.1477710074378115
# 3900 0.1582084880187764
# 4000 0.1626706778313007
# 4100 0.17402372529485283
# 4200 0.19120729759583732
# 4300 0.19769272670966734
# 4400 0.22799828567839348
# 4500 0.2597575732540096
# 4600 0.2857290640650936
# 4700 0.31958098028394966
# 4800 0.38126677886665244
# 4900 0.4724049818789015
# 5000 0.8945100111034296
# 0 0.02310157
# 500 0.007257657
# 1000 0.005194839
# 1500 0.011057438
# 2000 0.00303533
# 2500 0.002822762
# 3000 0.0020591936
# 3500 0.0031999664
# 4000 0.0031978136
# 4500 0.002991917
# 5000 0.0028131544
# 5500 0.0026572677
# 6000 0.0025203142
# 6500 0.0023995605
# 7000 0.0023304962
# 7500 0.0008052145
# 8000 0.0008555324
# 8500 0.0007219078
# 9000 0.0006568429
# 9500 0.0006570741
# 2073
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c3ea11c8acd8> in <module>
#      13
#      14 print(np.sum(np.absolute(lab-gt)))
# ---> 15 print(np.sum(np.absolute(labels-gt)))
#
# NameError: name 'labels' is not defined

# %%
c = np.matmul(allFeat,W) -Sig
lab = np.argmax(c, axis =1)
plt.scatter(c[:, 1],
            c[:, 2],
             c=gt, alpha=0.1)
plt.colorbar()
print(np.sum(np.absolute(lab-gt)))
# Out:
# 3783

# %%
import umap

embed = umap.UMAP().fit(allFeat)
f = embed.transform(allFeat)
plt.scatter(f[:, 0],
            f[:, 1],
             c=gt, alpha=0.1)
kmeans = KMeans(n_clusters=3, random_state=0).fit(f)
labelF = kmeans.predict(f)

# %%
def clusteringScore(lab, gt):
    numClus = np.max(gt)+1
    scores = np.zeros(numClus)
    for i in range(numClus):
        mask = gt == i
        for j in range(numClus):
            trialMask = lab == j
            s = np.sum(trialMask==mask)
            if s > scores[i]:
                scores[i] = s
    return scores
            
print(clusteringScore(lab, gt)    )
print(clusteringScore(labelK, gt)    )
print(clusteringScore(labelK, gt)    )
# Out:
# [2859. 2886. 2905.]
# [2763. 2822. 2927.]

# %%
def multiModelX(feat,  meanEst, sigEst, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    dist_ = tf.math.pow(projDist_-Sig_, 2)
    
    top2 = tf.math.top_k(-dist_, 3).values
    dCost = top2[:,0]/top2[:,1]
    selfCost = tf.reduce_sum(dCost)/numFeat_

    final_cost = selfCost + lambda_*regularizer_


    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)            
            #a = sess.run(dCost)
            #print(a.shape)
            #print(a[:10])
            #k = donk
            if i%500 == 0:               
                d = sess.run(final_cost)
                print(i, d)

        W = sess.run(W_)
        Sig = sess.run(Sig_)
    return W, Sig

# %%
from sklearn.cluster import KMeans

numClass = 3
kmeans = KMeans(n_clusters=numClass, random_state=0).fit(allFeat)
means = kmeans.cluster_centers_

means = means/np.linalg.norm(means, axis =1, keepdims=True)
sigInit = np.zeros([numClass])
labels = kmeans.predict(allFeat)
for i in range(numClass):
    mask = labels == i
    sigInit[i] = np.mean(np.matmul(allFeat, np.transpose(means)))


score = np.min(kmeans.transform(allFeat), axis =1)
val = np.percentile(score, 50)
maskK = score<val

    
c = np.matmul(allFeat, np.transpose(means)) - sigInit
plt.scatter(c[:feat1.shape[0], 0],
            c[:feat1.shape[0], 1],
            color='red', alpha=0.1)
plt.scatter(c[feat1.shape[0]:, 0],
            c[feat1.shape[0]:, 1],
            color='blue', alpha=0.1)
plt.show();

# %%
tf.reset_default_graph()

WIni = copy.deepcopy(np.transpose(means))
SigIni = copy.deepcopy(np.transpose(sigInit))


WW, SigS = multiModelX(allFeat[maskK,:], WIni, SigIni, numIter= 100000)
# Out:
# 0 0.19762689
# 500 0.0148220165
# 1000 0.0057787984
# 1500 0.0028814129
# 2000 0.0016607968
# 2500 0.0010551005
# 3000 0.00072035176
# 3500 0.0005180621
# 4000 0.00038896865
# 4500 0.00030171374
# 5000 0.0002405409
# 5500 0.0001958856
# 6000 0.00016245649
# 6500 0.00013658006
# 7000 0.00011612658
# 7500 9.981035e-05
# 8000 8.649755e-05
# 8500 7.544778e-05
# 9000 6.619866e-05
# 9500 5.8337697e-05
# 10000 5.1798364e-05
# 10500 4.6129153e-05
# 11000 4.1196126e-05
# 11500 3.6868652e-05
# 12000 3.3189266e-05
# 12500 2.9904624e-05
# 13000 2.7045338e-05
# 13500 2.453232e-05
# 14000 2.2256569e-05
# 14500 2.0303803e-05
# 15000 1.8552779e-05
# 15500 1.6850776e-05
# 16000 1.5607442e-05
# 16500 1.4096329e-05
# 17000 1.3148627e-05
# 17500 1.1950908e-05
# 18000 1.1054819e-05
# 18500 1.0229592e-05
# 19000 9.40007e-06
# 19500 8.6998325e-06
# 20000 8.130323e-06
# 20500 7.450229e-06
# 21000 6.940802e-06
# 21500 6.4233936e-06
# 22000 5.9824015e-06
# 22500 5.572289e-06
# 23000 5.210065e-06
# 23500 4.777293e-06
# 24000 4.526193e-06
# 24500 4.232711e-06
# 25000 3.9661463e-06
# 25500 3.6561657e-06
# 26000 3.4571717e-06
# 26500 3.2636008e-06
# 27000 2.9627793e-06
# 27500 2.7518001e-06
# 28000 2.6725409e-06
# 28500 2.588391e-06
# 29000 2.4092406e-06
# 29500 2.190753e-06
# 30000 2.013183e-06
# 30500 1.918264e-06
# 31000 1.8950459e-06
# 31500 1.806319e-06
# 32000 1.6376351e-06
# 32500 1.47718e-06
# 33000 1.4290987e-06
# 33500 1.4091802e-06
# 34000 1.4048212e-06
# 34500 1.2533699e-06
# 35000 1.1309562e-06
# 35500 1.0569316e-06
# 36000 1.008235e-06
# 36500 9.559308e-07
# 37000 8.966387e-07
# 37500 8.5069547e-07
# 38000 8.1007533e-07
# 38500 7.702828e-07
# 39000 7.3591394e-07
# 39500 6.834207e-07
# 40000 6.251803e-07
# 40500 5.926721e-07
# 41000 5.446864e-07
# 41500 5.1802823e-07
# 42000 5.018785e-07
# 42500 5.127228e-07
# 43000 6.245334e-07
# 43500 5.6857044e-07
# 44000 4.593207e-07
# 44500 4.648396e-07
# 45000 4.303372e-07
# 45500 3.7204762e-07
# 46000 3.1053918e-07
# 46500 2.933035e-07
# 47000 2.749803e-07
# 47500 2.5383787e-07
# 48000 2.411232e-07
# 48500 2.4586188e-07
# 49000 3.5539932e-07
# 49500 5.556084e-07
# 50000 3.0389268e-07
# 50500 1.9917398e-07
# 51000 1.7760681e-07
# 51500 1.6548206e-07
# 52000 1.5791436e-07
# 52500 1.5174149e-07
# 53000 1.4478414e-07
# 53500 1.3796485e-07
# 54000 1.3124325e-07
# 54500 1.2681379e-07
# 55000 1.2623785e-07
# 55500 1.2892248e-07
# 56000 1.3101238e-07
# 56500 1.2820365e-07
# 57000 1.5067924e-07
# 57500 1.8708533e-07
# 58000 1.9427472e-07
# 58500 1.6126539e-07
# 59000 1.2282595e-07
# 59500 1.084218e-07
# 60000 1.03410535e-07
# 60500 9.984799e-08
# 61000 1.021441e-07
# 61500 9.4499875e-08
# 62000 8.013061e-08
# 62500 7.312295e-08
# 63000 6.7259464e-08
# 63500 6.243892e-08
# 64000 6.01343e-08
# 64500 5.6119664e-08
# 65000 4.9821207e-08
# 65500 4.546896e-08
# 66000 4.3557147e-08
# 66500 4.1743622e-08
# 67000 3.9025426e-08
# 67500 3.6153917e-08
# 68000 3.458408e-08
# 68500 3.3091677e-08
# 69000 3.1679843e-08
# 69500 3.0399846e-08
# 70000 2.9297858e-08
# 70500 2.8401967e-08
# 71000 2.770497e-08
# 71500 2.7195023e-08
# 72000 2.6133852e-08
# 72500 2.6070827e-08
# 73000 2.54388e-08
# 73500 2.5235884e-08
# 74000 2.6556886e-08
# 74500 2.8100024e-08
# 75000 6.2089896e-08
# 75500 1.8767294e-07
# 76000 2.0188442e-07
# 76500 8.461698e-08
# 77000 3.4955075e-08
# 77500 1.9437019e-08
# 78000 1.7498037e-08
# 78500 1.6914118e-08
# 79000 1.5230512e-08
# 79500 1.4700005e-08
# 80000 1.390026e-08
# 80500 1.3000117e-08
# 81000 1.2673343e-08
# 81500 1.2080949e-08
# 82000 1.1733822e-08
# 82500 1.1410102e-08
# 83000 1.0973459e-08
# 83500 1.0601617e-08
# 84000 1.0110163e-08
# 84500 1.057177e-08
# 85000 1.1049213e-08
# 85500 1.0485803e-08
# 86000 1.0079447e-08
# 86500 9.795908e-09
# 87000 9.526444e-09
# 87500 9.268686e-09
# 88000 9.016291e-09
# 88500 8.591741e-09
# 89000 8.115207e-09
# 89500 7.898756e-09
# 90000 7.686499e-09
# 90500 7.49047e-09
# 91000 7.3021087e-09
# 91500 7.119387e-09
# 92000 6.939858e-09
# 92500 6.7790946e-09
# 93000 6.6215105e-09
# 93500 6.504389e-09
# 94000 6.364898e-09
# 94500 6.494054e-09
# 95000 6.396916e-09
# 95500 6.2819416e-09
# 96000 6.1552496e-09
# 96500 5.976278e-09
# 97000 6.1513847e-09
# 97500 6.457627e-09
# 98000 6.349213e-09
# 98500 6.2366596e-09
# 99000 6.14041e-09
# 99500 6.0414584e-09

# %%
c = np.matmul(allFeat,WW) -SigS

# %%
plt.scatter(c[maskK, 0],
            c[maskK, 1],
             c=gt[maskK], alpha=0.1)
plt.figure()

plt.scatter(c[maskK, 1],
            c[maskK, 2],
             c=gt[maskK], alpha=0.1)

plt.figure()

plt.scatter(c[maskK, 0],
            c[maskK, 2],
             c=gt[maskK], alpha=0.1)
plt.colorbar()
