# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

allFeat = np.load('/tf/notebooks/clusteringTree/stl_feat/feats_2048.npy')
gtAll = np.load('/tf/notebooks/clusteringTree/stl_feat/labels_2048.npy')-1

# %%
# %load_ext autoreload
# %autoreload

from sklearn.cluster import KMeans
from clusteringX2 import normIt
from clusteringX2 import clusterModel
from clusteringX2 import train_step3


def clustering(feat, numClass=60, thres=0.1):
    feat, m = normIt(feat)
    
    # initilization
    kmeans = KMeans(n_clusters=numClass, random_state=0).fit(feat)
    labelK = kmeans.predict(feat)
    means =np.zeros([numClass, feat.shape[1]])

    for i in range(numClass):
        mask = labelK == i
        means[i,:] = np.mean(feat[mask,:], axis =0)

    sigInit = np.zeros([numClass])
    for i in range(numClass):
        mask = np.logical_not(labelK == i)
        sigInit[i] = np.mean(np.matmul(feat[mask,:], np.transpose(means[i,:])))
    model = clusterModel(means.transpose(), sigInit)
    train_step3(model, feat.astype("float32"), iter =100)
    
    
    
    c = model(feat.astype("float32"))
    s = np.max(c, axis=1)
    t = np.mean(s)
    mask = s > t*0.5
    train_step3(model, feat[mask,:].astype("float32"), iter =100)
    
    
    c = model(feat.astype("float32"))
    s = np.max(c, axis=1)
    t = np.mean(s)
    mask = s > t*0.5
    train_step3(model, feat[mask,:].astype("float32"), iter =100)

 
    c = model(feat.astype("float32"))
    labels = np.argmax(c, axis =1)
    mask_ = np.zeros(numClass, dtype=bool)
        
    for i in range(numClass):
        if np.sum(labels==i)>0:
            mask_[i] = 1
    w = model.w.numpy()
    sig = model.sig.numpy()
    w = w[:,mask_]
    sig = sig[mask_]
            

    return w, sig, m, mask
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class Node:
    def __init__(self, mask=None, w=None, sig=None, m=None):
        self.mask = mask
        self.w = w
        self.sig = sig
        self.m = m
            
class Layer:
    def __init__(self):
        self.nodeList = []
        
class Tree:
    def __init__(self):
        self.numLayers = 0
        self.listOfLayers = []
        self.numNodes = 0
        self.listOfNodes = []
        
    def addNode(self, c):
        self.listOfNodes.append(c)
        self.numNodes = self.numNodes + 1
        
    def addLayer(self, c):
        self.listOfLayers.append(c)
        self.numLayers = self.numLayers + 1

    
def startTree(allFeat, numClass=2):
    tree = Tree()    
    w, sig, m, inMask = clustering(allFeat, numClass)
    mask = np.ones(allFeat.shape[0], dtype=bool)
    #mask[np.logical_not(inMask)] = 0
    n = Node(mask, w, sig, m)

    tree.addNode(n)
    newLayer = Layer()
    newLayer.nodeList.append(tree.numNodes-1)
    tree.addLayer(newLayer)
    
    return tree

    
#mask = np.logical_or(gtAll==0,  gtAll==2)
mask = gtAll <10

feat = allFeat[mask,:]
gt = gtAll[mask]    
gtCoarseAll = np.logical_or.reduce( [gtAll == 0, gtAll == 2, gtAll == 8, gtAll == 9]).astype(int)   
gtCoarse = gtCoarseAll[mask]

tree = startTree(feat[::2])

# %%
def dataProjection(feat, node):
    x, _ = normIt(feat, node.m) 
    return np.matmul(x, node.w) - node.sig


    

def extendTree(tree, allFeat, numClass=2, clusteringThreshold=100):
    newLayer = Layer()
    lastLayer = tree.listOfLayers[-1]
    for nodeIndex in lastLayer.nodeList:
        node = tree.listOfNodes[nodeIndex]
        curFeat = allFeat[node.mask,:]
        score = dataProjection(curFeat, node)
        plt.scatter(score[:,0], score[:,1], alpha=0.1)
        
        clusterInd = np.argmax(score, axis =1)
        curInd = np.where(node.mask)[0]

        for i in range(score.shape[1]):
            subMask = clusterInd == i
            if sum(subMask) > clusteringThreshold:
                
                newMask =  np.zeros(allFeat.shape[0], dtype=bool)
                newMask[curInd[subMask]] = 1
                

                w, sig, m, inMask = clustering(allFeat[newMask,:], numClass)
                #subInd = np.where(newMask)[0]
                #newMask[subInd[np.logical_not(inMask)]] = 0

                if w.shape[1]>=2:
                    n = Node(newMask, w, sig, m)
                    tree.addNode(n)
                    newLayer.nodeList.append(tree.numNodes-1)
    tree.addLayer(newLayer)


        

# extendTree(tree, feat)
extendTree(tree, feat[::2])

# %%
def projectTree(feat, tree, maxClus=2, unit_vector=True, scale2data=True, verboise=True):
    
    projectionSpace = np.zeros([feat.shape[0], tree.numNodes*maxClus])
    
    cur = 0
    
    for i, n in enumerate(tree.listOfNodes):
        
        f = dataProjection(feat, n)
        numDim = f.shape[1]
        if unit_vector:
            f = f/np.linalg.norm(f, axis =1, keepdims=True)
        if scale2data:
            f = f*np.sum(n.mask)/n.mask.size 
        projectionSpace[:, cur:cur+numDim] = f
        cur = cur+numDim
        
        if verboise == True:
            print(i, n)
    projectionSpace = projectionSpace[:,:cur]
    return projectionSpace
        
#projectionSpace = projectTree(feat, tree, unit_vector=False)

# %%
def projectTree2(feat, tree, maxClus=2, unit_vector=True, scale2data=True, verboise=True):
    
    projectionSpace = np.zeros([feat.shape[0], tree.numNodes*maxClus])
    
    cur = 0
    
    for i, n in enumerate(tree.listOfNodes):
        
        f = dataProjection(feat, n)
        numDim = f.shape[1]
        if unit_vector:
            f_ = np.concatenate([f, 10*np.ones([f.shape[0],1])], axis =1)
            f_ = f_/np.linalg.norm(f_, axis =1, keepdims=True)
            f = f_[:,:numDim]
        if scale2data:
            f = f*np.sum(n.mask)/n.mask.size 
        projectionSpace[:, cur:cur+numDim] = f
        cur = cur+numDim
        
        if verboise == True:
            print(i, n)
    projectionSpace = projectionSpace[:,:cur]
    return projectionSpace
        
projectionSpace = projectTree2(feat, tree, unit_vector=False)
# Out:
# 0 <__main__.Node object at 0x7fa86c0fc7f0>
# 1 <__main__.Node object at 0x7fa7803ec828>
# 2 <__main__.Node object at 0x7fa7803bcdd8>
# 3 <__main__.Node object at 0x7fa780040278>
# 4 <__main__.Node object at 0x7fa76c5a1fd0>
# 5 <__main__.Node object at 0x7fa7800402b0>
# 6 <__main__.Node object at 0x7fa78030bbe0>
# 7 <__main__.Node object at 0x7fa76c3fdf98>

# %%
from sklearn.metrics import pairwise_distances

def test_feat(feat, labels, nBest= 1000):
    num_feat = feat.shape[0]
    d = pairwise_distances(feat)
    ind = np.argsort(d, axis =1)
    
    err = np.zeros(num_feat)
    
    for i in range(num_feat):
        l = labels[ind[i,:nBest+1]]      
        err[i] = nBest - (sum((l-l[0]) == 0))+1
                          
    return err



#projectionSpace = projectTree3(feat, tree, unit_vector=True, scale2data=True)
projectionSpace = projectTree2(feat, tree, unit_vector=False, scale2data=True)

pp = projectionSpace.copy()

nBest = 500

# err = test_feat(pp[:,:2], gt, nBest=nBest)
# print(np.mean(err))
err = test_feat(pp[1::2], gt[1::2], nBest=nBest)
print(np.mean(err))
print('num dimenions:', pp.shape[1])
# Out:
# 0 <__main__.Node object at 0x7fa86c0fc7f0>
# 1 <__main__.Node object at 0x7fa7803ec828>
# 2 <__main__.Node object at 0x7fa7803bcdd8>
# 3 <__main__.Node object at 0x7fa780040278>
# 4 <__main__.Node object at 0x7fa76c5a1fd0>
# 5 <__main__.Node object at 0x7fa7800402b0>
# 6 <__main__.Node object at 0x7fa78030bbe0>
# 7 <__main__.Node object at 0x7fa76c3fdf98>
# 0.0
# num dimenions: 16

# %%
pp = projectTree2(allFeat[gtAll==0], tree, unit_vector=False, scale2data=True)

pp_out = projectTree2(allFeat[np.logical_not(gtAll==0)], tree, unit_vector=False, scale2data=True)
# Out:
# 0 <__main__.Node object at 0x7fa6703e7358>
# 1 <__main__.Node object at 0x7fa6882bca58>
# 2 <__main__.Node object at 0x7fa688344c50>
# 3 <__main__.Node object at 0x7fa64c459748>
# 4 <__main__.Node object at 0x7fa79271cf28>
# 5 <__main__.Node object at 0x7fa64c459780>
# 6 <__main__.Node object at 0x7fa7926a6ba8>
# 7 <__main__.Node object at 0x7fa7924f45c0>
# 8 <__main__.Node object at 0x7fa792442550>
# 9 <__main__.Node object at 0x7fa79238b6a0>
# 10 <__main__.Node object at 0x7fa7924f45f8>
# 11 <__main__.Node object at 0x7fa79238b780>
# 12 <__main__.Node object at 0x7fa7922b3b00>
# 13 <__main__.Node object at 0x7fa792114390>
# 14 <__main__.Node object at 0x7fa7920bdf98>
# 15 <__main__.Node object at 0x7fa791f6c860>
# 16 <__main__.Node object at 0x7fa791f3f710>
# 17 <__main__.Node object at 0x7fa791f6c898>
# 18 <__main__.Node object at 0x7fa791e9c208>
# 19 <__main__.Node object at 0x7fa791ea1ac8>
# 20 <__main__.Node object at 0x7fa791d0b320>
# 21 <__main__.Node object at 0x7fa791eaf860>
# 22 <__main__.Node object at 0x7fa791c37898>
# 23 <__main__.Node object at 0x7fa791b8f1d0>
# 24 <__main__.Node object at 0x7fa791b69198>
# 25 <__main__.Node object at 0x7fa791ac48d0>
# 26 <__main__.Node object at 0x7fa791abaef0>
# 27 <__main__.Node object at 0x7fa791afaba8>
# 28 <__main__.Node object at 0x7fa791a31390>
# 29 <__main__.Node object at 0x7fa7919fe8d0>
# 30 <__main__.Node object at 0x7fa791957a58>
# 31 <__main__.Node object at 0x7fa791855518>
# 32 <__main__.Node object at 0x7fa791868d30>
# 33 <__main__.Node object at 0x7fa7918b0630>
# 34 <__main__.Node object at 0x7fa7917d9898>
# 35 <__main__.Node object at 0x7fa7918815c0>
# 36 <__main__.Node object at 0x7fa7917e79e8>
# 37 <__main__.Node object at 0x7fa79183f208>
# 38 <__main__.Node object at 0x7fa7916849b0>
# 39 <__main__.Node object at 0x7fa791648748>
# 40 <__main__.Node object at 0x7fa791677e48>
# 41 <__main__.Node object at 0x7fa7915d0940>
# 42 <__main__.Node object at 0x7fa7915f6978>
# 43 <__main__.Node object at 0x7fa791656828>
# 44 <__main__.Node object at 0x7fa7915422b0>
# 45 <__main__.Node object at 0x7fa7914d9fd0>
# 46 <__main__.Node object at 0x7fa7914e64a8>
# 47 <__main__.Node object at 0x7fa7915423c8>
# 48 <__main__.Node object at 0x7fa791bee0b8>
# 49 <__main__.Node object at 0x7fa688365780>
# 50 <__main__.Node object at 0x7fa64c480e10>
# 51 <__main__.Node object at 0x7fa7914b6fd0>
# 52 <__main__.Node object at 0x7fa7914bbfd0>
# 53 <__main__.Node object at 0x7fa64c6088d0>
# 54 <__main__.Node object at 0x7fa7924dfba8>
# 55 <__main__.Node object at 0x7fa791455668>
# 56 <__main__.Node object at 0x7fa7924c83c8>
# 57 <__main__.Node object at 0x7fa7913af940>
# 58 <__main__.Node object at 0x7fa791455c88>
# 59 <__main__.Node object at 0x7fa79135e080>
# 60 <__main__.Node object at 0x7fa64c3c7b00>
# 61 <__main__.Node object at 0x7fa64c3b3be0>
# 62 <__main__.Node object at 0x7fa64c30bac8>
# 63 <__main__.Node object at 0x7fa64c2677f0>
# 64 <__main__.Node object at 0x7fa64c23f0f0>
# 65 <__main__.Node object at 0x7fa64c2b4400>
# 66 <__main__.Node object at 0x7fa64c1c2630>
# 67 <__main__.Node object at 0x7fa64c2355f8>
# 68 <__main__.Node object at 0x7fa64c1b7d30>
# 69 <__main__.Node object at 0x7fa64c121358>
# 70 <__main__.Node object at 0x7fa64c0eb898>
# 71 <__main__.Node object at 0x7fa64c0938d0>
# 72 <__main__.Node object at 0x7fa64c1717f0>
# 73 <__main__.Node object at 0x7fa64c05c208>
# 74 <__main__.Node object at 0x7fa6447b2f60>
# 75 <__main__.Node object at 0x7fa6447dc0f0>
# 76 <__main__.Node object at 0x7fa64478f6a0>
# 77 <__main__.Node object at 0x7fa64c05c320>
# 78 <__main__.Node object at 0x7fa6446ef518>
# 79 <__main__.Node object at 0x7fa644732748>
# 80 <__main__.Node object at 0x7fa6446a5fd0>
# 81 <__main__.Node object at 0x7fa644635be0>
# 82 <__main__.Node object at 0x7fa6446a5f98>
# 83 <__main__.Node object at 0x7fa6445e8128>
# 84 <__main__.Node object at 0x7fa6445038d0>
# 85 <__main__.Node object at 0x7fa6444c2b38>
# 86 <__main__.Node object at 0x7fa644509438>
# 87 <__main__.Node object at 0x7fa6444f7908>
# 88 <__main__.Node object at 0x7fa6443ace80>
# 89 <__main__.Node object at 0x7fa6443f56a0>
# 90 <__main__.Node object at 0x7fa6443528d0>
# 91 <__main__.Node object at 0x7fa6442ba0b8>
# 92 <__main__.Node object at 0x7fa6442ea400>
# 93 <__main__.Node object at 0x7fa644203208>
# 94 <__main__.Node object at 0x7fa6442ad668>
# 0 <__main__.Node object at 0x7fa6703e7358>
# 1 <__main__.Node object at 0x7fa6882bca58>
# 2 <__main__.Node object at 0x7fa688344c50>
# 3 <__main__.Node object at 0x7fa64c459748>
# 4 <__main__.Node object at 0x7fa79271cf28>
# 5 <__main__.Node object at 0x7fa64c459780>
# 6 <__main__.Node object at 0x7fa7926a6ba8>
# 7 <__main__.Node object at 0x7fa7924f45c0>
# 8 <__main__.Node object at 0x7fa792442550>
# 9 <__main__.Node object at 0x7fa79238b6a0>
# 10 <__main__.Node object at 0x7fa7924f45f8>
# 11 <__main__.Node object at 0x7fa79238b780>
# 12 <__main__.Node object at 0x7fa7922b3b00>
# 13 <__main__.Node object at 0x7fa792114390>
# 14 <__main__.Node object at 0x7fa7920bdf98>
# 15 <__main__.Node object at 0x7fa791f6c860>
# 16 <__main__.Node object at 0x7fa791f3f710>
# 17 <__main__.Node object at 0x7fa791f6c898>
# 18 <__main__.Node object at 0x7fa791e9c208>
# 19 <__main__.Node object at 0x7fa791ea1ac8>
# 20 <__main__.Node object at 0x7fa791d0b320>
# 21 <__main__.Node object at 0x7fa791eaf860>
# 22 <__main__.Node object at 0x7fa791c37898>
# 23 <__main__.Node object at 0x7fa791b8f1d0>
# 24 <__main__.Node object at 0x7fa791b69198>
# 25 <__main__.Node object at 0x7fa791ac48d0>
# 26 <__main__.Node object at 0x7fa791abaef0>
# 27 <__main__.Node object at 0x7fa791afaba8>
# 28 <__main__.Node object at 0x7fa791a31390>
# 29 <__main__.Node object at 0x7fa7919fe8d0>
# 30 <__main__.Node object at 0x7fa791957a58>
# 31 <__main__.Node object at 0x7fa791855518>
# 32 <__main__.Node object at 0x7fa791868d30>
# 33 <__main__.Node object at 0x7fa7918b0630>
# 34 <__main__.Node object at 0x7fa7917d9898>
# 35 <__main__.Node object at 0x7fa7918815c0>
# 36 <__main__.Node object at 0x7fa7917e79e8>
# 37 <__main__.Node object at 0x7fa79183f208>
# 38 <__main__.Node object at 0x7fa7916849b0>
# 39 <__main__.Node object at 0x7fa791648748>
# 40 <__main__.Node object at 0x7fa791677e48>
# 41 <__main__.Node object at 0x7fa7915d0940>
# 42 <__main__.Node object at 0x7fa7915f6978>
# 43 <__main__.Node object at 0x7fa791656828>
# 44 <__main__.Node object at 0x7fa7915422b0>
# 45 <__main__.Node object at 0x7fa7914d9fd0>
# 46 <__main__.Node object at 0x7fa7914e64a8>
# 47 <__main__.Node object at 0x7fa7915423c8>
# 48 <__main__.Node object at 0x7fa791bee0b8>
# 49 <__main__.Node object at 0x7fa688365780>
# 50 <__main__.Node object at 0x7fa64c480e10>
# 51 <__main__.Node object at 0x7fa7914b6fd0>
# 52 <__main__.Node object at 0x7fa7914bbfd0>
# 53 <__main__.Node object at 0x7fa64c6088d0>
# 54 <__main__.Node object at 0x7fa7924dfba8>
# 55 <__main__.Node object at 0x7fa791455668>
# 56 <__main__.Node object at 0x7fa7924c83c8>
# 57 <__main__.Node object at 0x7fa7913af940>
# 58 <__main__.Node object at 0x7fa791455c88>
# 59 <__main__.Node object at 0x7fa79135e080>
# 60 <__main__.Node object at 0x7fa64c3c7b00>
# 61 <__main__.Node object at 0x7fa64c3b3be0>
# 62 <__main__.Node object at 0x7fa64c30bac8>
# 63 <__main__.Node object at 0x7fa64c2677f0>
# 64 <__main__.Node object at 0x7fa64c23f0f0>
# 65 <__main__.Node object at 0x7fa64c2b4400>
# 66 <__main__.Node object at 0x7fa64c1c2630>
# 67 <__main__.Node object at 0x7fa64c2355f8>
# 68 <__main__.Node object at 0x7fa64c1b7d30>
# 69 <__main__.Node object at 0x7fa64c121358>
# 70 <__main__.Node object at 0x7fa64c0eb898>
# 71 <__main__.Node object at 0x7fa64c0938d0>
# 72 <__main__.Node object at 0x7fa64c1717f0>
# 73 <__main__.Node object at 0x7fa64c05c208>
# 74 <__main__.Node object at 0x7fa6447b2f60>
# 75 <__main__.Node object at 0x7fa6447dc0f0>
# 76 <__main__.Node object at 0x7fa64478f6a0>
# 77 <__main__.Node object at 0x7fa64c05c320>
# 78 <__main__.Node object at 0x7fa6446ef518>
# 79 <__main__.Node object at 0x7fa644732748>
# 80 <__main__.Node object at 0x7fa6446a5fd0>
# 81 <__main__.Node object at 0x7fa644635be0>
# 82 <__main__.Node object at 0x7fa6446a5f98>
# 83 <__main__.Node object at 0x7fa6445e8128>
# 84 <__main__.Node object at 0x7fa6445038d0>
# 85 <__main__.Node object at 0x7fa6444c2b38>
# 86 <__main__.Node object at 0x7fa644509438>
# 87 <__main__.Node object at 0x7fa6444f7908>
# 88 <__main__.Node object at 0x7fa6443ace80>
# 89 <__main__.Node object at 0x7fa6443f56a0>
# 90 <__main__.Node object at 0x7fa6443528d0>
# 91 <__main__.Node object at 0x7fa6442ba0b8>
# 92 <__main__.Node object at 0x7fa6442ea400>
# 93 <__main__.Node object at 0x7fa644203208>
# 94 <__main__.Node object at 0x7fa6442ad668>

# %%
plt.scatter(pp[:,0], pp[:,1], alpha =0.01)

# %%
pp_ = pp/np.linalg.norm(pp, axis=1, keepdims=True)
pp_out_ = pp_out/np.linalg.norm(pp_out, axis=1, keepdims=True)

# %%
from sklearn.neighbors import KernelDensity
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(pp_[::2])
in_score = kde.score_samples(pp_[1::2])
out_score = kde.score_samples(pp_out_)

plt.figure(0)
plt.hist(in_score)
plt.figure(1)
plt.hist(out_score)
# Out:
# (array([  46.,  749., 1351., 2051., 1694., 1316.,  484., 1364., 1175.,
#         1470.]), array([116.14878976, 117.54222118, 118.9356526 , 120.32908402,
#         121.72251544, 123.11594686, 124.50937828, 125.9028097 ,
#         127.29624112, 128.68967254, 130.08310396]), <a list of 10 Patch objects>)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

allScore = np.concatenate([in_score, out_score])
binTrue = np.concatenate([np.ones(in_score.size), np.zeros(out_score.size)])


auc = roc_auc_score(binTrue, allScore)
print(auc)
# Out:
# 0.9808335305719921

# %%
our_score = np.mean(pp, axis =1)
plt.figure(0)
plt.hist(our_score)

our_score_out = np.mean(pp_out, axis =1)
plt.figure(1)
plt.hist(our_score_out)
# Out:
# (array([  52.,  464., 1294., 2322., 3120., 2606., 1309.,  421.,  102.,
#           10.]),
#  array([1.76090582, 1.8801091 , 1.99931239, 2.11851567, 2.23771896,
#         2.35692224, 2.47612553, 2.59532882, 2.7145321 , 2.83373539,
#         2.95293867]),
#  <a list of 10 Patch objects>)

# %%
from sklearn.svm import OneClassSVM

clf = OneClassSVM(gamma='auto').fit(pp)
s = clf.score_samples(pp)

# %%
projectionSpace_out = projectTree2(allFeat[np.logical_not(gtAll==0)], tree, unit_vector=False, scale2data=True)
# Out:
# 0 <__main__.Node object at 0x7fa86c0fc7f0>
# 1 <__main__.Node object at 0x7fa7803ec828>
# 2 <__main__.Node object at 0x7fa7803bcdd8>
# 3 <__main__.Node object at 0x7fa780040278>
# 4 <__main__.Node object at 0x7fa76c5a1fd0>
# 5 <__main__.Node object at 0x7fa7800402b0>
# 6 <__main__.Node object at 0x7fa78030bbe0>
# 7 <__main__.Node object at 0x7fa76c3fdf98>

# %%
s_out = clf.score_samples(projectionSpace_out)
plt.figure(0)
plt.hist(s_out)

plt.figure(1)
plt.hist(s)
# Out:
# (array([  8.,  13.,  43.,  83., 149., 267., 382., 231., 109.,  15.]),
#  array([ 3.7407398 ,  6.12119489,  8.50164999, 10.88210508, 13.26256017,
#         15.64301526, 18.02347035, 20.40392545, 22.78438054, 25.16483563,
#         27.54529072]),
#  <a list of 10 Patch objects>)

# %%
f_norm, _ = normIt(allFeat)
fTrain = f_norm[gtAll==0]
fTest = f_norm[np.logical_not(gtAll==0)]

clf_ori = OneClassSVM(gamma='auto').fit(fTrain[::2])
s_ori = clf_ori.score_samples(fTrain[1::2])
s_test = clf_ori.score_samples(fTest)

# %%
plt.figure(0)
plt.hist(s_ori)

plt.figure(1)
plt.hist(s_test)
# Out:
# (array([ 290., 2005., 2629., 1671., 1363., 1417., 1214.,  833.,  260.,
#           18.]), array([324.63365154, 324.64459111, 324.65553067, 324.66647024,
#         324.67740981, 324.68834938, 324.69928894, 324.71022851,
#         324.72116808, 324.73210765, 324.74304722]), <a list of 10 Patch objects>)

# %%
allScore = np.concatenate([s_ori, s_test])
binTrue = np.concatenate([np.ones(s_ori.size), np.zeros(s_test.size)])


auc = roc_auc_score(binTrue, allScore)
print(auc)
# Out:
# 0.9871069033530572

# %%
i = 10
plt.scatter(pp[:,i], pp[:,i+1], c=gt, alpha =0.01)

# %%
k = donk

# %%
! pip3 install umap.learn
# Out:
# Collecting umap.learn
#   Downloading https://files.pythonhosted.org/packages/ad/92/36bac74962b424870026cb0b42cec3d5b6f4afa37d81818475d8762f9255/umap-learn-0.3.10.tar.gz (40kB)
#      |████████████████████████████████| 40kB 4.0MB/s eta 0:00:011
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.6/dist-packages (from umap.learn) (1.18.1)
# Requirement already satisfied: scikit-learn>=0.16 in /usr/local/lib/python3.6/dist-packages (from umap.learn) (0.22.1)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.6/dist-packages (from umap.learn) (1.4.1)
# Collecting numba>=0.37
#   Downloading https://files.pythonhosted.org/packages/ba/49/61522f34b1333aa4e9aa02005dc0774d25bd234400dff718b16615d6a744/numba-0.48.0-cp36-cp36m-manylinux1_x86_64.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 7.2MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.16->umap.learn) (0.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.37->umap.learn) (44.0.0)
# Collecting llvmlite<0.32.0,>=0.31.0dev0
#   Downloading https://files.pythonhosted.org/packages/ad/bb/60d4033d56c9da36490af19caa6c794b72b8aef6f792fdfa8cb95d11e419/llvmlite-0.31.0-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#      |████████████████████████████████| 20.2MB 9.3MB/s eta 0:00:01    |███████████▍                    | 7.2MB 9.3MB/s eta 0:00:02     |████████████████████████▉       | 15.6MB 9.3MB/s eta 0:00:01
# Building wheels for collected packages: umap.learn
#   Building wheel for umap.learn (setup.py) ... done
#   Created wheel for umap.learn: filename=umap_learn-0.3.10-cp36-none-any.whl size=44352 sha256=ba6e6f4c8cbc35c20d37c52bbeefb657711d41e451d9cfeb666827552ada34b3
#   Stored in directory: /root/.cache/pip/wheels/d0/f8/d5/8e3af3ee957feb9b403a060ebe72f7561887fef9dea658326e
# Successfully built umap.learn
# Installing collected packages: llvmlite, numba, umap.learn
# Successfully installed llvmlite-0.31.0 numba-0.48.0 umap.learn
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip uninstall -y enum34

! pip3 install hdbscan
# Out:
# Uninstalling enum34-1.1.6:
#   Successfully uninstalled enum34-1.1.6
# Collecting hdbscan
#   Downloading https://files.pythonhosted.org/packages/8a/a6/2524f6cff01a2da18f07f6a2b04977297f8a094ef3a92aa6bfc6c3924687/hdbscan-0.8.25.tar.gz (4.4MB)
#      |████████████████████████████████| 4.4MB 7.5MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting cython>=0.27
#   Using cached https://files.pythonhosted.org/packages/d1/54/9d66ee2180776dfe33c2b8cc2f2b67c343fd9d80de91ac0edc5bc346fb06/Cython-0.29.15-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: scikit-learn>=0.17 in /usr/local/lib/python3.6/dist-packages (from hdbscan) (0.22.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hdbscan) (1.13.0)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.6/dist-packages (from hdbscan) (1.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from hdbscan) (1.18.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from hdbscan) (0.14.1)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.25-cp36-cp36m-linux_x86_64.whl size=2361062 sha256=e8174dbfe579b11dc7fed7b118a6290bd310adfa528eaae663ea7758903825da
#   Stored in directory: /root/.cache/pip/wheels/9c/c0/c3/233f1760ffcf845291955c8aa53e0a81b695bec07780ee5935
# Successfully built hdbscan
# Installing collected packages: cython, hdbscan
# Successfully installed cython-0.29.15 hdbscan-0.8.25
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import umap

f_norm, _ = normIt(feat)
embedding = umap.UMAP()
embedding.fit(f_norm[::2])
ump_ori = embedding.transform(f_norm[1::2])

plt.scatter(ump_ori[:,0], ump_ori[:,1], c=gt[1::2], alpha =0.1)

# %%
plt.figure(0)
ump_ori = embedding.transform(f_norm[::2])
plt.scatter(ump_ori[:,0], ump_ori[:,1], c=gt[::2], alpha =0.01)
plt.figure(1)
ump_ori = embedding.transform(f_norm[1::2])
plt.scatter(ump_ori[:,0], ump_ori[:,1], c=gt[1::2], alpha =0.01)

# %%
import umap


embedding = umap.UMAP()
embedding.fit(pp[::2])
ump_pp = embedding.transform(pp[1::2])
plt.scatter(ump_pp[:,0], ump_pp[:,1], c=gt[1::2], alpha =0.1)

# %%
plt.figure(0)
ump_pp = embedding.transform(pp[::2])
plt.scatter(ump_pp[:,0], ump_pp[:,1], c=gt[::2], alpha =0.01)
plt.figure(1)
ump_pp = embedding.transform(pp[1::2])
plt.scatter(ump_pp[:,0], ump_pp[:,1], c=gt[1::2], alpha =0.01)

# %%
plt.scatter(ump_pp[:,0], ump_pp[:,1], c=gt, alpha =0.01)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4283             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4284                 colors = mcolors.to_rgba_array(c)
#    4285                 n_elem = colors.shape[0]
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     239         # Test dimensionality to reject single floats.
# --> 240         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     241     # Return a tuple to prevent the cached value from being modified.
#
# ValueError: Invalid RGBA argument: 0.0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-9d000c5bcd9c> in <module>
# ----> 1 plt.scatter(ump_pp[:,0], ump_pp[:,1], c=gt, alpha =0.01)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4451             self._parse_scatter_color_args(
#    4452                 c, edgecolors, kwargs, xshape, yshape,
# -> 4453                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4454
#    4455         if plotnonfinite and colors is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4295                         "acceptable for use with 'x' with size {xs}, "
#    4296                         "'y' with size {ys}."
# -> 4297                             .format(nc=n_elem, xs=xsize, ys=ysize)
#    4298                     )
#    4299                 else:
#
# ValueError: 'c' argument has 6500 elements, which is not acceptable for use with 'x' with size 3250, 'y' with size 3250.

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN()
clusterer.fit(pp)
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_epsilon=0.0,
#         cluster_selection_method='eom', core_dist_n_jobs=4,
#         gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=5, min_samples=None, p=None,
#         prediction_data=False)

# %%
plt.scatter(ump_pp[:,0], ump_pp[:,1], c=clusterer.labels_, alpha =0.01)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4283             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4284                 colors = mcolors.to_rgba_array(c)
#    4285                 n_elem = colors.shape[0]
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     239         # Test dimensionality to reject single floats.
# --> 240         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     241     # Return a tuple to prevent the cached value from being modified.
#
# ValueError: Invalid RGBA argument: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-4c159b775b81> in <module>
# ----> 1 plt.scatter(ump_pp[:,0], ump_pp[:,1], c=clusterer.labels_, alpha =0.01)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4451             self._parse_scatter_color_args(
#    4452                 c, edgecolors, kwargs, xshape, yshape,
# -> 4453                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4454
#    4455         if plotnonfinite and colors is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4295                         "acceptable for use with 'x' with size {xs}, "
#    4296                         "'y' with size {ys}."
# -> 4297                             .format(nc=n_elem, xs=xsize, ys=ysize)
#    4298                     )
#    4299                 else:
#
# ValueError: 'c' argument has 6500 elements, which is not acceptable for use with 'x' with size 3250, 'y' with size 3250.

# %%
clusterer = hdbscan.HDBSCAN()
clusterer.fit(pp[gtCoarse==1])
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_epsilon=0.0,
#         cluster_selection_method='eom', core_dist_n_jobs=4,
#         gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=5, min_samples=None, p=None,
#         prediction_data=False)

# %%
plt.scatter(ump_pp[gtCoarse==1,0], ump_pp[gtCoarse==1,1], c=clusterer.labels_, alpha =0.01)

# %%
err = test_feat(pp, gt, nBest=1000)
print(np.mean(err))

# %%
plt.hist(err)

# %%
k= donk

# %%
feat_ = allFeat[gtAll==0,:]
tree2 = startTree(feat_[::2])
pp2 = projectTree(feat_, tree2, unit_vector=False)
pp2a = projectTree(allFeat[gtAll==1,:], tree2, unit_vector=False)

# %%
plt.scatter(pp2[:,0], pp2[:,1], alpha =0.1)

plt.scatter(pp2a[:,0], pp2a[:,1], alpha =0.1)

# %%
k = dnk

# %%
outlier_feat = allFeat[gtAll==9,:]


ff_out = np.concatenate([feat,outlier_feat], axis = 0)
out_gt = np.concatenate([gt, -1*np.ones(outlier_feat.shape[0])])

# %%
def test_feat(feat, labels, nBest= 1000):
    num_feat = feat.shape[0]
    d = pairwise_distances(feat)
    ind = np.argsort(d, axis =1)
    
    err = np.zeros(num_feat)
    
    for i in range(num_feat):
        l = labels[ind[i,:nBest+1]]      
        #print(l)
        err[i] = nBest - (sum((l-l[0]) == 0))+1
                          
    return err




projectionOutlier = projectTree(ff_out, tree);
projectionOutlier = projectionOutlier/np.linalg.norm(projectionOutlier, axis =1, keepdims=True)

err = test_feat(projectionOutlier[:,:], out_gt, nBest=10)
print(np.mean(err))

# %%
print(err)

# %%
print(projectionOutlier.shape)

# %%
plt.scatter(projectionOutlier[:,0], projectionOutlier[:,1], c = out_gt, alpha =0.01)

# %%
def projectTreeTmp(feat, tree, numClus=2):
    
    projectionSpace = np.zeros([feat.shape[0], tree.numNodes*numClus])
    
    for i, n in enumerate(tree.listOfNodes):
        f = dataProjection(feat, n)
        f = f/np.linalg.norm(f, axis =1, keepdims=True)
        projectionSpace[:, i*2:i*2+2] = f
        print(i, n)
    return projectionSpace

projectionOutlier = projectTreeTmp(ff_out, tree);
err = test_feat(projectionOutlier[:,:], out_gt, nBest=10)
print(np.mean(err))

# %%
print(np.exp(1))

# %%
plt.scatter(projectionOutlier[:,0], projectionOutlier[:,1], c = out_gt, alpha =0.1)

# %%
k_feat = feat.copy()
k_m = np.mean(k_feat[::2], axis=0)
k_feat = k_feat - k_m
k_feat = k_feat/np.linalg.norm(k_feat, axis=1, keepdims=True)

kmeans = KMeans(n_clusters=6, random_state=0).fit(k_feat[::2])

# %%
k_f = kmeans.transform(k_feat)
err = test_feat(k_f, gt, nBest=10)
print(np.mean(err))

# %%
plt.scatter(k_f[:,0], k_f[:,1], c = gt, alpha =0.01)

# %%
outlier_feat = allFeat[gtAll==9,:].copy()
outlier_feat = outlier_feat -k_m
outlier_feat = outlier_feat/np.linalg.norm(outlier_feat, axis=1, keepdims=True)

k_out = np.concatenate([k_feat,outlier_feat], axis = 0)
k_gt = np.concatenate([gt, -1*np.ones(outlier_feat.shape[0])])

k_f = kmeans.transform(k_out)
err = test_feat(k_out, k_gt, nBest=10)
print(np.mean(err))
