# %%
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras import backend as K
import numpy as np

import dirUtil 
from highDimLearning import vgg2feat

import tensorflow as tf

from sklearn.metrics.pairwise import euclidean_distances

import matplotlib.pyplot as plt




    

def feat2labels(feat):
    numClass = len(feat)
    numDim = feat[0].shape[1]
    numPts = 0
    for i in range(numClass):
        numPts = numPts + feat[i].shape[0]

    allFeat = np.zeros([numPts, numDim])
    allLabels = np.zeros(numPts, dtype = int)
    cur = 0
    for i in range(numClass):
        allFeat[cur:cur+feat[i].shape[0],:] = feat[i]
        allLabels[cur:cur+feat[i].shape[0]] = i
        cur = cur + feat[i].shape[0]
    return allFeat, allLabels
        
    


trainingNum = 1000

tf.reset_default_graph()
K.clear_session()
folder = '/media/daniel/D/code/keras-tutorial/animals/dogs/'
feats = dirUtil.dir2vgg16(folder)
feat1 = vgg2feat(feats)


folder2 = '/media/daniel/D/code/keras-tutorial/animals/cats/'
tf.reset_default_graph()
K.clear_session()
feats = dirUtil.dir2vgg16(folder2)
feat2 = vgg2feat(feats)

folder3 = '/media/daniel/D/code/keras-tutorial/animals/panda/'
tf.reset_default_graph()
K.clear_session()
feats = dirUtil.dir2vgg16(folder3)
feat3 = vgg2feat(feats)

allFeat, gt = feat2labels([feat1, feat2, feat3])

# %%
import numpy as np
import tensorflow as tf
import copy

from sklearn.cluster import KMeans



def multiModelB(feat,  meanEst, sigEst, sigA, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    Sig_adv = tf.get_variable("Sa", dtype=tf.float32,
                            initializer=sigA.astype("float32"))

    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


   


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    
    projDiff = projDist_-Sig_
    dist_ = tf.math.pow(projDiff,2)

    
    advCost = tf.reduce_max(projDiff, axis=1)
    #advCost = tf.nn.relu(advCost)     
    advCost = tf.math.pow(advCost, 2)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/(advCost+0.0001)
    selfCost = tf.reduce_sum(selfCost)/numFeat_
    
    
    
    assign_ = tf.math.softmax(projDiff/0.01)
    dist_2 = 0.01*tf.math.abs(projDiff- Sig_ -Sig_adv)
    #dist_2 = tf.math.pow(projDiff- Sig_ -Sig_adv, 2)
    dCost = dist_2 *assign_
    dCost = tf.reduce_sum(dist_2, axis =1)
    dCost = tf.reduce_sum(dCost)/numFeat_
    
    final_cost = selfCost + lambda_*regularizer_ + 1.0*dCost

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)


        W = sess.run(W_)
        Sig = sess.run(Sig_)
        SigAdv = sess.run(Sig_adv)
    return W, Sig, SigAdv
        

def multiModel2B(feat,  meanEst, sigEst, sigA, initMask, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    Sig_adv = tf.get_variable("Sa", dtype=tf.float32,
                           initializer=sigA.astype("float32"))

    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")

    
    mask = tf.placeholder("float", feat.shape[0])
    numInMask = tf.placeholder("float", shape=())
        
    
    
    
    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    
    projDiff = projDist_-Sig_
    dist_ = tf.math.pow(projDiff,2)

    
    advCost = tf.reduce_max(projDiff, axis=1)
    advCost = tf.nn.relu(advCost)     
    advCost = tf.math.pow(advCost, 2)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/(advCost+0.0001)
    selfCost = mask*selfCost
    selfCost = tf.reduce_sum(selfCost)/numInMask
    
    
    
    assign_ = tf.math.softmax(projDiff/0.01)
    dist_2 = 0.01*tf.math.abs(projDiff- Sig_ -Sig_adv)
    #dist_2 = tf.math.pow(projDiff- Sig_ -Sig_adv, 2)
    dCost = dist_2 *assign_
    dCost = tf.reduce_sum(dist_2, axis =1)
    dCost = mask*dCost
    dCost = tf.reduce_sum(dCost)/numInMask
    
    final_cost = selfCost + lambda_*regularizer_ + 1.0*dCost
    
    
    

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        curMask = copy.deepcopy(initMask)
        curNum = sum(curMask)
        for i in range(5001):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})
            a = sess.run(advCost, feed_dict={mask: curMask, numInMask: curNum})
            if i%100 == 0 and i >0:
                W = sess.run(W_)
                Sig = sess.run(Sig_)
                c = np.matmul(feat,W) -Sig
                ns = np.max(c,axis=1)
                thres = np.percentile(ns,50- i/100.0)
                curMask = np.logical_and(ns>thres, ns>0.01)
                curNum = np.sum(curMask)
                print(i,thres)

        for i in range(10000):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})

        W = sess.run(W_)
        Sig = sess.run(Sig_)
        SigAdv = sess.run(Sig_adv)

    return W, Sig, SigAdv
        



def clusterData(allFeat, numClass=2):

    tf.reset_default_graph()
    
    
    
    #    k-means initilization
    kmeans = KMeans(n_clusters=numClass, random_state=0).fit(allFeat)
    means = kmeans.cluster_centers_
    means = means/np.linalg.norm(means, axis =1, keepdims=True)
    sigInit = np.zeros([numClass])
    labelK = kmeans.predict(allFeat)
    for i in range(numClass):
        mask = labelK == i
        sigInit[i] = np.mean(np.matmul(allFeat[mask,:], np.transpose(means)))
    
    W = copy.deepcopy(np.transpose(means))
    Sig = copy.deepcopy(np.transpose(sigInit))
        
    score = np.min(kmeans.transform(allFeat), axis =1)
    val = np.percentile(score, 50)
    maskK = score<val


    #W, Sig, SigA = multiModelB(allFeat[maskK,:], W, Sig, Sig,
    #                    weight=1.0, numIter=10000)
    
    W, Sig, SigA = multiModelB(allFeat[maskK,:], W, Sig, Sig,
                        weight=1.0, numIter=10000)
    c = np.matmul(allFeat,W) -Sig
    label = np.argmax(c, axis =1)
    #return W, Sig, SigA, label, c, labelK 


    
    tf.reset_default_graph()
    W, Sig, SigA = multiModel2B(allFeat, W, Sig, SigA, maskK, weight=1.0, numIter=10000)
    
    #tf.reset_default_graph()
    #W, Sig, SigA = multiModelB(allFeat, W, Sig, SigA,
    #                  weight=1.0, numIter=10000)

    c = np.matmul(allFeat,W) -Sig
    label = np.argmax(c, axis =1)
    return W, Sig, SigA, label, c, labelK

# %%
import numpy as np
import tensorflow as tf
import copy

from sklearn.cluster import KMeans



def multiModelB(feat,  meanEst, sigEst, sigA, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    Sig_adv = tf.get_variable("Sa", dtype=tf.float32,
                            initializer=sigA.astype("float32"))

    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")


   


    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    
    projDiff = projDist_-Sig_
    dist_ = tf.math.pow(projDiff,2)

    
    advCost = tf.reduce_max(projDiff, axis=1)
    #advCost = tf.nn.relu(advCost)     
    advCost = tf.math.pow(advCost, 2)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/(advCost+0.0001)
    selfCost = tf.reduce_sum(selfCost)/numFeat_
    
    
    
    assign_ = tf.math.softmax(projDiff/0.01)
    dist_2 = 0.01*tf.math.abs(projDiff- Sig_ -Sig_adv)
    #dist_2 = tf.math.pow(projDiff- Sig_ -Sig_adv, 2)
    dCost = dist_2 *assign_
    dCost = tf.reduce_sum(dist_2, axis =1)
    dCost = tf.reduce_sum(dCost)/numFeat_
    
    final_cost = selfCost + lambda_*regularizer_ + 1.0*dCost

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(numIter):
            sess.run(train)
            if i%500 == 0:
               
                d = sess.run(final_cost)
                print(i, d)


        W = sess.run(W_)
        Sig = sess.run(Sig_)
        SigAdv = sess.run(Sig_adv)
    return W, Sig, SigAdv
        

def multiModel2B(feat,  meanEst, sigEst, sigA, initMask, weight=0.0, numIter=10000):

    numDim = meanEst.shape[1]

    f_ = tf.constant(feat, dtype="float32")
    W_ = tf.get_variable("W", dtype=tf.float32,
                         initializer=meanEst.astype("float32"))
    Sig_ = tf.get_variable("S", dtype=tf.float32,
                           initializer=sigEst.astype("float32"))
    Sig_adv = tf.get_variable("Sa", dtype=tf.float32,
                           initializer=sigA.astype("float32"))

    lambda_ = tf.constant(weight, dtype="float32")
    numFeat_ = tf.constant(feat.shape[0], dtype="float32")

    
    mask = tf.placeholder("float", feat.shape[0])
    numInMask = tf.placeholder("float", shape=())
        
    
    
    
    projDist_ = tf.matmul(f_, W_)

    meanNorm_ = tf.sqrt(tf.reduce_sum(tf.math.square(W_), axis=0))
    regularizer_ = 0.0*tf.math.abs(1-Sig_) + (1-meanNorm_)*(1-meanNorm_)
    regularizer_ = tf.reduce_sum(regularizer_)

    
    projDiff = projDist_-Sig_
    dist_ = tf.math.pow(projDiff,2)

    
    advCost = tf.reduce_max(projDiff, axis=1)
    advCost = tf.nn.relu(advCost)     
    advCost = tf.math.pow(advCost, 2)
    selfCost = tf.reduce_sum(dist_, axis=1)
    selfCost = (selfCost-advCost)/(advCost+0.0001)
    selfCost = mask*selfCost
    selfCost = tf.reduce_sum(selfCost)/numInMask
    
    
    
    assign_ = tf.math.softmax(projDiff/0.01)
    dist_2 = 0.01*tf.math.abs(projDiff- Sig_ -Sig_adv)
    #dist_2 = tf.math.pow(projDiff- Sig_ -Sig_adv, 2)
    dCost = dist_2 *assign_
    dCost = tf.reduce_sum(dist_2, axis =1)
    dCost = mask*dCost
    dCost = tf.reduce_sum(dCost)/numInMask
    
    final_cost = selfCost + lambda_*regularizer_ + 1.0*dCost
    
    
    

    optimizer = tf.train.GradientDescentOptimizer(0.01)
    train = optimizer.minimize(final_cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        curMask = copy.deepcopy(initMask)
        curNum = sum(curMask)
        for i in range(5001):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})
            a = sess.run(advCost, feed_dict={mask: curMask, numInMask: curNum})
            if i%100 == 0 and i >0:
                W = sess.run(W_)
                Sig = sess.run(Sig_)
                c = np.matmul(feat,W) -Sig
                ns = np.max(c,axis=1)
                thres = np.percentile(ns,50- i/100.0)
                curMask = ns>thres
                #curMask = np.logical_and(ns>thres, ns>0.01)
                curNum = np.sum(curMask)
                print(i,thres)

        for i in range(10000):
            sess.run(train, feed_dict={mask: curMask, numInMask: curNum})

        W = sess.run(W_)
        Sig = sess.run(Sig_)
        SigAdv = sess.run(Sig_adv)

    return W, Sig, SigAdv
        



def clusterData(allFeat, numClass=2):

    tf.reset_default_graph()
    
    #embed = umap.UMAP().fit(allFeat)
    #f = embed.transform(allFeat)
    
    f = allFeat
    kmeans = KMeans(n_clusters=numClass, random_state=0).fit(f)
    labelK = kmeans.predict(f)
    means =np.zeros([numClass, allFeat.shape[1]])

    for i in range(numClass):
        mask = labelK == i
        means[i,:] = np.mean(allFeat[mask,:], axis =0)
        
    means = means/np.linalg.norm(means, axis =1, keepdims=True)
    sigInit = np.zeros([numClass])
    for i in range(numClass):
        mask = np.logical_not(labelK == i)
        sigInit[i] = np.mean(np.matmul(allFeat[mask,:], np.transpose(means[i,:])))

    score = np.min(kmeans.transform(f), axis =1)    
    val = np.percentile(score, 50)
    maskK = score<val


    W = copy.deepcopy(np.transpose(means))
    Sig = copy.deepcopy(np.transpose(sigInit))
        

    
    W, Sig, SigA = multiModelB(allFeat[maskK,:], W, Sig, Sig,
                        weight=1.0, numIter=10000)
    c = np.matmul(allFeat,W) -Sig
    label = np.argmax(c, axis =1)
    #return W, Sig, SigA, label, c, labelK 


    
    tf.reset_default_graph()
    W, Sig, SigA = multiModel2B(allFeat, W, Sig, SigA, maskK, weight=1.0, numIter=10000)
    
    #tf.reset_default_graph()
    #W, Sig, SigA = multiModelB(allFeat, W, Sig, SigA,
    #                  weight=1.0, numIter=10000)

    c = np.matmul(allFeat,W) -Sig
    label = np.argmax(c, axis =1)
    return W, Sig, SigA, label, c, labelK

# %%
allFeat, gt = feat2labels([feat2])

W, Sig, SigA, lab, c, labelK = clusterData(allFeat, numClass=2)


plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
            c=gt, alpha=0.1)
plt.figure()
plt.scatter(c[:, 0],
            c[:, 1],
            c=lab, alpha=0.1)

print(np.sum(np.absolute(lab-gt)))
print(np.sum(np.absolute(labelK-gt)))
# Out:
# 0 0.1661568
# 500 0.01218995
# 1000 0.010663498
# 1500 0.009555428
# 2000 0.008625709
# 2500 0.0077999155
# 3000 0.007040962
# 3500 0.0063294815
# 4000 0.0056521143
# 4500 0.0050011
# 5000 0.0043703984
# 5500 0.0037555536
# 6000 0.0031538864
# 6500 0.0025628642
# 7000 0.0019806896
# 7500 0.0014061013
# 8000 0.00083987793
# 8500 0.0006788337
# 9000 0.0006515677
# 9500 0.0006298648
# 100 0.40063277287412113
# 200 0.39957340267416963
# 300 0.3990335564764125
# 400 0.39794092483272603
# 500 0.3970702771312329
# 600 0.39573559233615496
# 700 0.3946813727165497
# 800 0.39378823070318625
# 900 0.39321405818191624
# 1000 0.39109466632617684
# 1100 0.38877231239661414
# 1200 0.38733147578413774
# 1300 0.386774670837313
# 1400 0.38542035891824034
# 1500 0.3842932594558194
# 1600 0.38281864509934593
# 1700 0.3784622132516893
# 1800 0.37436553229957453
# 1900 0.37160769360280566
# 2000 0.3698017230071055
# 2100 0.3682083402978537
# 2200 0.3673516649580867
# 2300 0.3668493323282217
# 2400 0.36556154605145874
# 2500 0.3634179393494052
# 2600 0.3608481880492989
# 2700 0.3581005051217167
# 2800 0.3561110152132711
# 2900 0.35316219463692555
# 3000 0.35062075913850504
# 3100 0.34920222822499225
# 3200 0.34746253751369816
# 3300 0.34554409984040385
# 3400 0.3450695020217843
# 3500 0.3412740196523042
# 3600 0.33963744429663695
# 3700 0.3386754104858424
# 3800 0.336497937168886
# 3900 0.3343164120477963
# 4000 0.3301156747728605
# 4100 0.32839481407323773
# 4200 0.32477691322554136
# 4300 0.32116063732733224
# 4400 0.3180406644835022
# 4500 0.3140456542665033
# 4600 0.30201947961966935
# 4700 0.28689953700646653
# 4800 0.2673997182113973
# 4900 0.24796647382315512
# 5000 0.14457583697932083
# 1000
# 366

# %%
score = np.max(c, axis =1)

thres = np.median(score)

W, Sig, SigA, lab, c, labelK = clusterData(allFeat[score<thres,:], numClass=2)


a = np.argmax(c, axis =1)
print(sum(a==1))
# Out:
# 1000

# %%
nFeat, nGt = feat2labels([feat1, feat2])

c = np.matmul(nFeat,W) -Sig
d = c/np.linalg.norm(c, axis =1, keepdims=True)
plt.scatter(d[:, 0],
            d[:, 1],
             c=nGt, alpha=0.01)

plt.figure()

plt.scatter(d[:, 1],
            d[:, 2],
             c=nGt, alpha=0.01)

plt.figure()

plt.scatter(d[:, 0],
            d[:, 1],
             c=nGt, alpha=0.01)

# %%
nFeat, nGt = feat2labels([feat2])

c = np.matmul(nFeat,W) -Sig
d = c/np.linalg.norm(c, axis =1, keepdims=True)

kk = np.max(d, axis =1)
print(np.max(d, axis =1))

print(np.mean(kk))
plt.scatter(d[:, 0],
            d[:, 1],
             c=nGt, alpha=0.01)
# Out:
# [ 7.77106489e-01  9.97987364e-01  9.22530667e-01  7.94324467e-01
#   9.91467795e-01  9.29487509e-01  9.99542637e-01  8.90056606e-01
#   9.91367795e-01  9.99734509e-01  9.92289320e-01  8.50000552e-01
#   8.55331229e-01  9.91397424e-01  9.29519145e-01  9.54663141e-01
#   9.84728557e-01 -4.13198955e-01  9.83432763e-01  9.05252474e-01
#   9.70366958e-01  9.99938479e-01  8.95032770e-01  7.62552292e-01
#   9.94705350e-01  9.99997756e-01  1.78104890e-01  9.99399626e-01
#   8.73067508e-01  9.93016543e-01  9.99353903e-01  9.94095534e-01
#   9.90717727e-01  9.22373217e-01  8.80814193e-01  9.91251205e-01
#   9.88670284e-01  9.96948040e-01  9.90640228e-01  9.98820561e-01
#   9.89763276e-01  9.89015840e-01  9.80277089e-01  9.95631387e-01
#   9.60486635e-01  9.74680506e-01  9.54653581e-01  9.24043148e-01
#   9.85803189e-01 -1.00086810e-01  9.73883292e-01  9.94674778e-01
#   9.70945160e-01 -1.08295325e-04  8.14337779e-01  9.99854878e-01
#   7.34888546e-01  8.22561700e-01  9.84213880e-01  9.28090429e-01
#   9.08907570e-01  9.99379771e-01  9.97158503e-01  5.38882364e-01
#   4.26360147e-01  7.26058947e-01  6.93249785e-01  9.90419224e-01
#   9.99568062e-01  9.99727951e-01  9.89839113e-01  9.21245333e-01
#   5.19975660e-01  9.90168901e-01  9.34986659e-01  7.35973971e-01
#  -1.15580341e-01  7.23420304e-01  9.85888878e-01 -5.22777739e-01
#   9.97994133e-01  9.36571309e-01  8.94039186e-01  7.21098961e-01
#   9.77417228e-01  9.85544551e-01  9.97821776e-01  9.69578955e-01
#   9.42248709e-01  9.87837060e-01  9.15672410e-01  8.79853731e-01
#   9.62106677e-01  9.57527825e-01  7.30110906e-01  9.99998787e-01
#   9.83967437e-01  9.97418318e-01  9.87973500e-01  5.65379538e-01
#   8.78345609e-01  8.13706865e-01  9.58590915e-01  9.09454278e-01
#   9.38214956e-01  9.97590073e-01  9.73186904e-01  9.03283179e-01
#   9.51854761e-01  6.17567687e-01  9.97419402e-01  9.91959611e-01
#   9.36214465e-01  9.96842654e-01  9.71543328e-01  9.34352016e-01
#   9.68473005e-01  9.73326060e-01  9.48666528e-01  7.53847493e-01
#  -2.66077422e-01  8.37629717e-01  9.25265152e-01  9.86721882e-01
#   9.98588001e-01  9.77903811e-01  9.97975463e-01  9.39209818e-01
#   9.94822295e-01  9.84187823e-01  9.98150130e-01  9.78491460e-01
#   9.75595145e-01  9.77836829e-01  1.88313834e-01  9.12590523e-01
#   9.99758405e-01  9.97302799e-01  9.99522001e-01  9.89421145e-01
#   9.93151659e-01  9.89209123e-01  8.15213987e-01  2.76864815e-01
#   7.59329598e-01  9.80791290e-01  9.21922669e-01  7.08475281e-01
#   9.93162966e-01  9.65868727e-01  9.72894539e-01  9.87393574e-01
#   2.68882314e-01  9.99677629e-01  9.97636335e-01  9.87752060e-01
#   8.20719919e-01  9.55377155e-01  9.86558535e-01  8.75409378e-01
#  -4.49392340e-01  9.99943380e-01  5.41468732e-02  9.80835714e-01
#   9.89210072e-01  9.31294147e-01  9.97913558e-01  9.99198511e-01
#   9.96607257e-01  9.30086292e-01  8.63104499e-01  9.97907459e-01
#   8.51612018e-01  9.96335709e-01 -2.98370701e-01  8.03274583e-01
#   8.49019418e-01  9.97388050e-01  9.88491471e-01  9.90060483e-01
#   9.97028340e-01  7.70820382e-01  9.72853876e-01  9.83590263e-01]
# 0.8601420620611573

# %%
print(clusteringScore(lab, gt))
print(clusteringScore(labelK, gt))
print(clusteringScore(labelF, gt))
# Out:
# [1948. 1948.]
# [1832. 1832.]
# [0. 0.]
# /home/daniel/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.

# %%
c = np.matmul(allFeat,W2) -Sig2
lab = np.argmax(c, axis =1)
plt.scatter(c[:, 0],
            c[:, 1],
             c=gt, alpha=0.1)

# %%
c = np.matmul(allFeat,W) -Sig
lab = np.argmax(c, axis =1)
plt.scatter(c[:, 2],
            c[:, 1],
             c=gt, alpha=0.1)
plt.colorbar()
plt.figure()
plt.scatter(c[:, 2],
            c[:, 1],
             c=lab, alpha=0.1)
plt.colorbar()


print(np.sum(np.absolute(lab-gt)))
# Out:
# 3903

# %%
nn = c/np.linalg.norm(c, axis =1, keepdims =True)
kmeans = KMeans(n_clusters=3, random_state=0).fit(nn)
labelKF = kmeans.predict(nn)

plt.scatter(nn[:, 0],
            nn[:, 1],
             c=gt, alpha=0.1)

# %%
import umap

embed = umap.UMAP().fit(allFeat)
f = embed.transform(allFeat)
plt.scatter(f[:, 0],
            f[:, 1],
             c=gt, alpha=0.1)
kmeans = KMeans(n_clusters=3, random_state=0).fit(f)
labelF = kmeans.predict(f)

# %%
def clusteringScore(lab, gt):
    numClus = np.max(gt)+1
    scores = np.zeros(numClus)
    for i in range(numClus):
        mask = gt == i
        for j in range(numClus):
            trialMask = lab == j
            s = np.sum(trialMask==mask)
            if s > scores[i]:
                scores[i] = s
    return scores
            
print(clusteringScore(lab, gt))
print(clusteringScore(labelKF, gt))
print(clusteringScore(labelF, gt))
# Out:
# [2927. 2929. 2956.]
# [2929. 2932. 2951.]
# [2933. 2936. 2969.]

# %%
from sklearn.cluster import KMeans

numClass = 3
kmeans = KMeans(n_clusters=numClass, random_state=0).fit(allFeat)
means = kmeans.cluster_centers_

means = means/np.linalg.norm(means, axis =1, keepdims=True)
sigInit = np.zeros([numClass])
labels = kmeans.predict(allFeat)
for i in range(numClass):
    mask = labels == i
    sigInit[i] = np.mean(np.matmul(allFeat, np.transpose(means)))


score = np.min(kmeans.transform(allFeat), axis =1)
val = np.percentile(score, 50)
maskK = score<val

    
c = np.matmul(allFeat, np.transpose(means)) - sigInit
plt.scatter(c[:feat1.shape[0], 0],
            c[:feat1.shape[0], 1],
            color='red', alpha=0.1)
plt.scatter(c[feat1.shape[0]:, 0],
            c[feat1.shape[0]:, 1],
            color='blue', alpha=0.1)
plt.show();

# %%
tf.reset_default_graph()

WIni = copy.deepcopy(np.transpose(means))
SigIni = copy.deepcopy(np.transpose(sigInit))


WW, SigS = multiModelX(allFeat[maskK,:], WIni, SigIni, numIter= 100000)
# Out:
# 0 0.19762689
# 500 0.0148220165
# 1000 0.0057787984
# 1500 0.0028814129
# 2000 0.0016607968
# 2500 0.0010551005
# 3000 0.00072035176
# 3500 0.0005180621
# 4000 0.00038896865
# 4500 0.00030171374
# 5000 0.0002405409
# 5500 0.0001958856
# 6000 0.00016245649
# 6500 0.00013658006
# 7000 0.00011612658
# 7500 9.981035e-05
# 8000 8.649755e-05
# 8500 7.544778e-05
# 9000 6.619866e-05
# 9500 5.8337697e-05
# 10000 5.1798364e-05
# 10500 4.6129153e-05
# 11000 4.1196126e-05
# 11500 3.6868652e-05
# 12000 3.3189266e-05
# 12500 2.9904624e-05
# 13000 2.7045338e-05
# 13500 2.453232e-05
# 14000 2.2256569e-05
# 14500 2.0303803e-05
# 15000 1.8552779e-05
# 15500 1.6850776e-05
# 16000 1.5607442e-05
# 16500 1.4096329e-05
# 17000 1.3148627e-05
# 17500 1.1950908e-05
# 18000 1.1054819e-05
# 18500 1.0229592e-05
# 19000 9.40007e-06
# 19500 8.6998325e-06
# 20000 8.130323e-06
# 20500 7.450229e-06
# 21000 6.940802e-06
# 21500 6.4233936e-06
# 22000 5.9824015e-06
# 22500 5.572289e-06
# 23000 5.210065e-06
# 23500 4.777293e-06
# 24000 4.526193e-06
# 24500 4.232711e-06
# 25000 3.9661463e-06
# 25500 3.6561657e-06
# 26000 3.4571717e-06
# 26500 3.2636008e-06
# 27000 2.9627793e-06
# 27500 2.7518001e-06
# 28000 2.6725409e-06
# 28500 2.588391e-06
# 29000 2.4092406e-06
# 29500 2.190753e-06
# 30000 2.013183e-06
# 30500 1.918264e-06
# 31000 1.8950459e-06
# 31500 1.806319e-06
# 32000 1.6376351e-06
# 32500 1.47718e-06
# 33000 1.4290987e-06
# 33500 1.4091802e-06
# 34000 1.4048212e-06
# 34500 1.2533699e-06
# 35000 1.1309562e-06
# 35500 1.0569316e-06
# 36000 1.008235e-06
# 36500 9.559308e-07
# 37000 8.966387e-07
# 37500 8.5069547e-07
# 38000 8.1007533e-07
# 38500 7.702828e-07
# 39000 7.3591394e-07
# 39500 6.834207e-07
# 40000 6.251803e-07
# 40500 5.926721e-07
# 41000 5.446864e-07
# 41500 5.1802823e-07
# 42000 5.018785e-07
# 42500 5.127228e-07
# 43000 6.245334e-07
# 43500 5.6857044e-07
# 44000 4.593207e-07
# 44500 4.648396e-07
# 45000 4.303372e-07
# 45500 3.7204762e-07
# 46000 3.1053918e-07
# 46500 2.933035e-07
# 47000 2.749803e-07
# 47500 2.5383787e-07
# 48000 2.411232e-07
# 48500 2.4586188e-07
# 49000 3.5539932e-07
# 49500 5.556084e-07
# 50000 3.0389268e-07
# 50500 1.9917398e-07
# 51000 1.7760681e-07
# 51500 1.6548206e-07
# 52000 1.5791436e-07
# 52500 1.5174149e-07
# 53000 1.4478414e-07
# 53500 1.3796485e-07
# 54000 1.3124325e-07
# 54500 1.2681379e-07
# 55000 1.2623785e-07
# 55500 1.2892248e-07
# 56000 1.3101238e-07
# 56500 1.2820365e-07
# 57000 1.5067924e-07
# 57500 1.8708533e-07
# 58000 1.9427472e-07
# 58500 1.6126539e-07
# 59000 1.2282595e-07
# 59500 1.084218e-07
# 60000 1.03410535e-07
# 60500 9.984799e-08
# 61000 1.021441e-07
# 61500 9.4499875e-08
# 62000 8.013061e-08
# 62500 7.312295e-08
# 63000 6.7259464e-08
# 63500 6.243892e-08
# 64000 6.01343e-08
# 64500 5.6119664e-08
# 65000 4.9821207e-08
# 65500 4.546896e-08
# 66000 4.3557147e-08
# 66500 4.1743622e-08
# 67000 3.9025426e-08
# 67500 3.6153917e-08
# 68000 3.458408e-08
# 68500 3.3091677e-08
# 69000 3.1679843e-08
# 69500 3.0399846e-08
# 70000 2.9297858e-08
# 70500 2.8401967e-08
# 71000 2.770497e-08
# 71500 2.7195023e-08
# 72000 2.6133852e-08
# 72500 2.6070827e-08
# 73000 2.54388e-08
# 73500 2.5235884e-08
# 74000 2.6556886e-08
# 74500 2.8100024e-08
# 75000 6.2089896e-08
# 75500 1.8767294e-07
# 76000 2.0188442e-07
# 76500 8.461698e-08
# 77000 3.4955075e-08
# 77500 1.9437019e-08
# 78000 1.7498037e-08
# 78500 1.6914118e-08
# 79000 1.5230512e-08
# 79500 1.4700005e-08
# 80000 1.390026e-08
# 80500 1.3000117e-08
# 81000 1.2673343e-08
# 81500 1.2080949e-08
# 82000 1.1733822e-08
# 82500 1.1410102e-08
# 83000 1.0973459e-08
# 83500 1.0601617e-08
# 84000 1.0110163e-08
# 84500 1.057177e-08
# 85000 1.1049213e-08
# 85500 1.0485803e-08
# 86000 1.0079447e-08
# 86500 9.795908e-09
# 87000 9.526444e-09
# 87500 9.268686e-09
# 88000 9.016291e-09
# 88500 8.591741e-09
# 89000 8.115207e-09
# 89500 7.898756e-09
# 90000 7.686499e-09
# 90500 7.49047e-09
# 91000 7.3021087e-09
# 91500 7.119387e-09
# 92000 6.939858e-09
# 92500 6.7790946e-09
# 93000 6.6215105e-09
# 93500 6.504389e-09
# 94000 6.364898e-09
# 94500 6.494054e-09
# 95000 6.396916e-09
# 95500 6.2819416e-09
# 96000 6.1552496e-09
# 96500 5.976278e-09
# 97000 6.1513847e-09
# 97500 6.457627e-09
# 98000 6.349213e-09
# 98500 6.2366596e-09
# 99000 6.14041e-09
# 99500 6.0414584e-09

# %%
c = np.matmul(allFeat,WW) -SigS

# %%
plt.scatter(c[maskK, 0],
            c[maskK, 1],
             c=gt[maskK], alpha=0.1)
plt.figure()

plt.scatter(c[maskK, 1],
            c[maskK, 2],
             c=gt[maskK], alpha=0.1)

plt.figure()

plt.scatter(c[maskK, 0],
            c[maskK, 2],
             c=gt[maskK], alpha=0.1)
plt.colorbar()
