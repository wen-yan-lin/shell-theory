# %%
# %load_ext autoreload
# %autoreload
import ClusteringTree as CT
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
folder = '/home/daniel/Desktop/Changhao/animals/dogs/'
folder2 = '/home/daniel/Desktop/Changhao/animals/cats/'
folder3 = '/home/daniel/Desktop/Changhao/animals/panda/'

# %%
CT.run_knn_test(folder, n_neighbors=5, drop_rate=30)
# Out:
# - Our Clustering Algo
# 1 -th NN:  97.0 / 100
# 2 -th NN:  94.0 / 100
# 3 -th NN:  93.0 / 100
# 4 -th NN:  97.0 / 100
# 5 -th NN:  91.0 / 100
# Overall:  94.4 %
# ****************************************
#
# - Kmeans
# 1 -th NN:  97.0 / 100
# 2 -th NN:  95.0 / 100
# 3 -th NN:  88.0 / 100
# 4 -th NN:  93.0 / 100
# 5 -th NN:  91.0 / 100
# Overall:  92.8 %
# ****************************************
#
# - UMAP
# 1 -th NN:  66.0 / 100
# 2 -th NN:  70.0 / 100
# 3 -th NN:  64.0 / 100
# 4 -th NN:  63.0 / 100
# 5 -th NN:  68.0 / 100
# Overall:  66.2 %
# ****************************************
