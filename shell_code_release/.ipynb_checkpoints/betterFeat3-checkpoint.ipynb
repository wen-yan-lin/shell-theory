# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from clusteringX2 import normIt
from clusteringX2 import clusterModel
from clusteringX2 import train_step3




# allFeat = np.load('/tf/notebooks/clusteringTree/stl_feat/feats_2048.npy')
# gtAll = np.load('/tf/notebooks/clusteringTree/stl_feat/labels_2048.npy')-1

allFeat = np.load('/tf/notebooks/STL-10/danielFeat.npy')
gtAll = np.load('/tf/notebooks/STL-10/danielGt.npy')

# allFeat = np.load('../MIT-Places/quickTest/resNet50.npy')
# gtAll = np.load('../MIT-Places/quickTest/gt.npy')
gt = gtAll.copy()
feat, _ = normIt(allFeat)
# feat, _ = normIt(feat)
# feat, _ = normIt(feat)
# feat, _ = normIt(feat)
# feat, _ = normIt(feat)


# allFeat = np.load('/tf/notebooks/Food59/train/resNet50.npy')
# gtAll = np.load('/tf/notebooks/Food59/train/gt.npy')

# mask = gtAll<5
# allFeat = allFeat[mask]
# gtAll = gtAll[mask]

# %%
# %load_ext autoreload
# %autoreload


def clustering(feat, numClass=60, thres=0.1):
    feat, m = normIt(feat)
    
    # initilization
    kmeans = KMeans(n_clusters=numClass, random_state=0).fit(feat)
    labelK = kmeans.predict(feat)
    means =np.zeros([numClass, feat.shape[1]])

    for i in range(numClass):
        mask = labelK == i
        means[i,:] = np.mean(feat[mask,:], axis =0)

    sigInit = np.zeros([numClass])
    for i in range(numClass):
        mask = np.logical_not(labelK == i)
        sigInit[i] = np.mean(np.matmul(feat[mask,:], np.transpose(means[i,:])))
    model = clusterModel(means.transpose(), sigInit)
    train_step3(model, feat.astype("float32"), iter =100)
    
    
    
    c = model(feat.astype("float32"))
    s = np.max(c, axis=1)
    t = np.mean(s)
    mask = s > t*0.5
    train_step3(model, feat[mask,:].astype("float32"), iter =100)
    
    
    c = model(feat.astype("float32"))
    s = np.max(c, axis=1)
    t = np.mean(s)
    mask = s > t*0.5
    train_step3(model, feat[mask,:].astype("float32"), iter =100)

 
    c = model(feat.astype("float32"))
    labels = np.argmax(c, axis =1)
    mask_ = np.zeros(numClass, dtype=bool)
        
    for i in range(numClass):
        if np.sum(labels==i)>0:
            mask_[i] = 1
    w = model.w.numpy()
    sig = model.sig.numpy()
    w = w[:,mask_]
    sig = sig[mask_]
            

    return w, sig, m, mask

# %%
class Node:
    def __init__(self, mask=None, w=None, sig=None, m=None):
        self.mask = mask
        self.w = w
        self.sig = sig
        self.m = m
        self.listOfChildren = []
            
class Layer:
    def __init__(self):
        self.nodeList = []
        
class Tree:
    def __init__(self):
        self.numLayers = 0
        self.listOfLayers = []
        self.numNodes = 0
        self.listOfNodes = []
        
    def addNode(self, c):
        self.listOfNodes.append(c)
        self.numNodes = self.numNodes + 1
        
    def addLayer(self, c):
        self.listOfLayers.append(c)
        self.numLayers = self.numLayers + 1

    
def startTree(allFeat, numClass=60):
    tree = Tree()    
    w, sig, m, inMask = clustering(allFeat, numClass)
    mask = np.ones(allFeat.shape[0], dtype=bool)
    #mask[np.logical_not(inMask)] = 0
    n = Node(mask, w, sig, m)

    tree.addNode(n)
    newLayer = Layer()
    newLayer.nodeList.append(tree.numNodes-1)
    tree.addLayer(newLayer)
    
    return tree
#allFeat = allFeat/np.linalg.norm(allFeat, axis=1, keepdims=True)

# %%
    
def dataProjection(feat, node):
    x, _ = normIt(feat, node.m) 
    s = np.linalg.norm(node.w, axis =0, keepdims=True)
    return (np.matmul(x, node.w) - node.sig), s


def extendTree(tree, allFeat, numClass=2, clusteringThreshold=100):
    newLayer = Layer()
    lastLayer = tree.listOfLayers[-1]
    for nodeIndex in lastLayer.nodeList:
        node = tree.listOfNodes[nodeIndex]
        curFeat = allFeat[node.mask,:]
        score, _ = dataProjection(curFeat, node)
        
        clusterInd = np.argmax(score, axis =1)
        curInd = np.where(node.mask)[0]

        #########################################
        #_, m_sub = normIt(curFeat)
        #########################################
        
        for i in range(score.shape[1]):
            subMask = clusterInd == i
            if sum(subMask) > clusteringThreshold:
                
                newMask =  np.zeros(allFeat.shape[0], dtype=bool)
                newMask[curInd[subMask]] = 1
                
                
                #########################################
                #nF, m_sub = normIt(allFeat[newMask,:])
                #########################################

                #nF, m_sub = normIt(allFeat[newMask,:], m_sub)
                nF = allFeat[newMask,:]
                w, sig, m_sub, inMask = clustering(nF, numClass)

                print(w.shape, sum(newMask))
                if w.shape[1]>=2:
                    n = Node(newMask, w, sig, m_sub)
                    tree.addNode(n)
                    newLayer.nodeList.append(tree.numNodes-1)
                    node.listOfChildren.append(tree.numNodes-1)
                else:
                    node.listOfChildren.append(-1)
            else:
                node.listOfChildren.append(-1)
    tree.addLayer(newLayer)



        



def buildTree(feat, numClass=2):
    
    tree = startTree(feat, numClass=numClass)
    for k in range(100):
        extendTree(tree, feat, numClass=numClass)
    return tree

# %%
def projectTree2(feat, tree, maxClus=2, unit_vector=True, scale2data=True, verboise=True):
    
    projectionSpace = np.zeros([feat.shape[0], tree.numNodes*maxClus])
    
    cur = 0
    
    for i, n in enumerate(tree.listOfNodes):
        
        f, _ = dataProjection(feat, n)
        numDim = f.shape[1]
        if unit_vector:
            f_ = np.concatenate([f, 10*np.ones([f.shape[0],1])], axis =1)
            f_ = f_/np.linalg.norm(f_, axis =1, keepdims=True)
            f = f_[:,:numDim]
        if scale2data:
            f = f*np.sum(n.mask)/n.mask.size 
        projectionSpace[:, cur:cur+numDim] = f
        cur = cur+numDim
        
        if verboise == True:
            print(i, n)
    projectionSpace = projectionSpace[:,:cur]
    return projectionSpace

# %%
trees = []
hierFeat = []
for i in range(1):
    if i == 0:
        tree = buildTree(feat)
        trees.append(tree)
        projectionSpace = projectTree2(feat, tree, unit_vector=True, scale2data=True)
        pp = projectionSpace.copy()
        pp_s, _ = normIt(pp)
        hierFeat.append(pp_s)

    else:
       
        tree = buildTree(hierFeat[-1])
        trees.append(tree)
        projectionSpace = projectTree2(hierFeat[-1], tree, unit_vector=True, scale2data=True)
        pp = projectionSpace.copy()
        pp_s, _ = normIt(pp)
        hierFeat.append(pp_s)
# Out:
# (2048, 2) 7797
# (2048, 2) 5203
# (2048, 2) 4508
# (2048, 2) 3289
# (2048, 2) 2576
# (2048, 2) 2627
# (2048, 2) 1349
# (2048, 2) 3159
# (2048, 2) 1762
# (2048, 2) 1527
# (2048, 2) 1320
# (2048, 2) 1256
# (2048, 2) 1241
# (2048, 2) 1386
# (2048, 2) 729
# (2048, 2) 620
# (2048, 2) 1296
# (2048, 2) 1863
# (2048, 2) 865
# (2048, 2) 897
# (2048, 2) 830
# (2048, 2) 697
# (2048, 2) 744
# (2048, 2) 576
# (2048, 2) 637
# (2048, 2) 619
# (2048, 2) 619
# (2048, 2) 622
# (2048, 2) 685
# (2048, 2) 701
# (2048, 2) 382
# (2048, 2) 347
# (2048, 2) 372
# (2048, 2) 248
# (2048, 2) 692
# (2048, 2) 604
# (2048, 2) 911
# (2048, 2) 952
# (2048, 2) 441
# (2048, 2) 424
# (2048, 2) 386
# (2048, 2) 511
# (2048, 2) 397
# (2048, 2) 433
# (2048, 2) 346
# (2048, 2) 351
# (2048, 2) 295
# (2048, 2) 449
# (2048, 2) 256
# (2048, 2) 320
# (2048, 2) 246
# (2048, 2) 391
# (2048, 2) 306
# (2048, 2) 313
# (2048, 2) 289
# (2048, 2) 330
# (2048, 2) 299
# (2048, 2) 323
# (2048, 2) 424
# (2048, 2) 261
# (2048, 2) 343
# (2048, 2) 358
# (2048, 2) 150
# (2048, 2) 232
# (2048, 2) 186
# (2048, 2) 161
# (2048, 2) 178
# (2048, 2) 194
# (2048, 2) 119
# (2048, 2) 129
# (2048, 2) 388
# (2048, 2) 304
# (2048, 2) 355
# (2048, 2) 249
# (2048, 2) 392
# (2048, 2) 519
# (2048, 2) 418
# (2048, 2) 534
# (2048, 2) 256
# (2048, 2) 185
# (2048, 2) 230
# (2048, 2) 194
# (2048, 2) 192
# (2048, 2) 194
# (2048, 2) 258
# (2048, 2) 253
# (2048, 2) 193
# (2048, 2) 204
# (2048, 2) 230
# (2048, 2) 203
# (2048, 2) 160
# (2048, 2) 186
# (2048, 2) 189
# (2048, 2) 162
# (2048, 2) 149
# (2048, 2) 146
# (2048, 2) 200
# (2048, 2) 249
# (2048, 2) 109
# (2048, 2) 147
# (2048, 2) 165
# (2048, 2) 155
# (2048, 2) 129
# (2048, 2) 117
# (2048, 2) 189
# (2048, 2) 202
# (2048, 2) 156
# (2048, 2) 150
# (2048, 2) 153
# (2048, 2) 160
# (2048, 2) 140
# (2048, 2) 149
# (2048, 2) 160
# (2048, 2) 170
# (2048, 2) 142
# (2048, 2) 157
# (2048, 2) 160
# (2048, 2) 163
# (2048, 2) 227
# (2048, 2) 197
# (2048, 2) 127
# (2048, 2) 134
# (2048, 2) 193
# (2048, 2) 150
# (2048, 2) 198
# (2048, 2) 160
# (2048, 2) 134
# (2048, 2) 114
# (2048, 2) 116
# (2048, 2) 212
# (2048, 2) 176
# (2048, 2) 166
# (2048, 2) 138
# (2048, 2) 187
# (2048, 2) 168
# (2048, 2) 109
# (2048, 2) 140
# (2048, 2) 170
# (2048, 2) 222
# (2048, 2) 313
# (2048, 2) 206
# (2048, 2) 243
# (2048, 2) 175
# (2048, 2) 253
# (2048, 2) 281
# (2048, 2) 101
# (2048, 2) 155
# (2048, 2) 106
# (2048, 2) 130
# (2048, 2) 104
# (2048, 2) 104
# (2048, 2) 118
# (2048, 2) 140
# (2048, 2) 129
# (2048, 2) 124
# (2048, 2) 108
# (2048, 2) 105
# (2048, 2) 115
# (2048, 2) 115
# (2048, 2) 111
# (2048, 2) 104
# (2048, 2) 102
# (2048, 2) 107
# (2048, 2) 115
# (2048, 2) 134
# (2048, 2) 111
# (2048, 2) 121
# (2048, 2) 106
# (2048, 2) 104
# (2048, 2) 103
# (2048, 2) 120
# (2048, 2) 119
# (2048, 2) 130
# (2048, 2) 147
# (2048, 2) 166
# (2048, 2) 112
# (2048, 2) 138
# (2048, 2) 105
# (2048, 2) 113
# (2048, 2) 140
# (2048, 2) 181
# 0 <__main__.Node object at 0x7f7af0184320>
# 1 <__main__.Node object at 0x7f7a14617f28>
# 2 <__main__.Node object at 0x7f7a145e3ac8>
# 3 <__main__.Node object at 0x7f7a144f3e48>
# 4 <__main__.Node object at 0x7f7a202a0160>
# 5 <__main__.Node object at 0x7f7a20254ac8>
# 6 <__main__.Node object at 0x7f7a262a5eb8>
# 7 <__main__.Node object at 0x7f7a2622dbe0>
# 8 <__main__.Node object at 0x7f7a2624ebe0>
# 9 <__main__.Node object at 0x7f7a2617ceb8>
# 10 <__main__.Node object at 0x7f7a25fe1ef0>
# 11 <__main__.Node object at 0x7f7a25f5dba8>
# 12 <__main__.Node object at 0x7f7a2610eb38>
# 13 <__main__.Node object at 0x7f7a26056d30>
# 14 <__main__.Node object at 0x7f7a25d5b5c0>
# 15 <__main__.Node object at 0x7f7a25e44a20>
# 16 <__main__.Node object at 0x7f7a25b90e48>
# 17 <__main__.Node object at 0x7f7a25ac0a58>
# 18 <__main__.Node object at 0x7f7a25adad68>
# 19 <__main__.Node object at 0x7f7a25b90828>
# 20 <__main__.Node object at 0x7f7a25c5ce10>
# 21 <__main__.Node object at 0x7f7a25840b38>
# 22 <__main__.Node object at 0x7f7a257bacc0>
# 23 <__main__.Node object at 0x7f7a257a96d8>
# 24 <__main__.Node object at 0x7f7a25c69278>
# 25 <__main__.Node object at 0x7f7a2597cb00>
# 26 <__main__.Node object at 0x7f7a25557fd0>
# 27 <__main__.Node object at 0x7f7a254f4f98>
# 28 <__main__.Node object at 0x7f7a2548e5c0>
# 29 <__main__.Node object at 0x7f7a2542afd0>
# 30 <__main__.Node object at 0x7f7a25417f60>
# 31 <__main__.Node object at 0x7f7a255c8780>
# 32 <__main__.Node object at 0x7f7a2520ecf8>
# 33 <__main__.Node object at 0x7f7a2536cb38>
# 34 <__main__.Node object at 0x7f7a2519a160>
# 35 <__main__.Node object at 0x7f7a25279908>
# 36 <__main__.Node object at 0x7f7a250a2da0>
# 37 <__main__.Node object at 0x7f7a25172f28>
# 38 <__main__.Node object at 0x7f7a24f3b9e8>
# 39 <__main__.Node object at 0x7f7a24ea0dd8>
# 40 <__main__.Node object at 0x7f7a24e76048>
# 41 <__main__.Node object at 0x7f7a24fc86d8>
# 42 <__main__.Node object at 0x7f7a24d47e48>
# 43 <__main__.Node object at 0x7f7a24e5ccf8>
# 44 <__main__.Node object at 0x7f7a24d12d68>
# 45 <__main__.Node object at 0x7f7a24c85dd8>
# 46 <__main__.Node object at 0x7f7a24c48b00>
# 47 <__main__.Node object at 0x7f7a24de3f98>
# 48 <__main__.Node object at 0x7f7a24bef550>
# 49 <__main__.Node object at 0x7f7a24c6f2b0>
# 50 <__main__.Node object at 0x7f7a2575dfd0>
# 51 <__main__.Node object at 0x7f7a24aead68>
# 52 <__main__.Node object at 0x7f7a24a0a1d0>
# 53 <__main__.Node object at 0x7f7a24a47cc0>
# 54 <__main__.Node object at 0x7f7a24a016a0>
# 55 <__main__.Node object at 0x7f7a24a2df98>
# 56 <__main__.Node object at 0x7f7a24917470>
# 57 <__main__.Node object at 0x7f7a24911d30>
# 58 <__main__.Node object at 0x7f7a2489f8d0>
# 59 <__main__.Node object at 0x7f7a24ae5b38>
# 60 <__main__.Node object at 0x7f7a2484de48>
# 61 <__main__.Node object at 0x7f7a2487ae48>
# 62 <__main__.Node object at 0x7f7a24742198>
# 63 <__main__.Node object at 0x7f7a246f7be0>
# 64 <__main__.Node object at 0x7f7a246d4080>
# 65 <__main__.Node object at 0x7f7a246ea240>
# 66 <__main__.Node object at 0x7f7a24642cc0>
# 67 <__main__.Node object at 0x7f7a24605f28>
# 68 <__main__.Node object at 0x7f7a24573a58>
# 69 <__main__.Node object at 0x7f7a245a5828>
# 70 <__main__.Node object at 0x7f7a245f0eb8>
# 71 <__main__.Node object at 0x7f7a244d3da0>
# 72 <__main__.Node object at 0x7f7a24524ba8>
# 73 <__main__.Node object at 0x7f7a244ac208>
# 74 <__main__.Node object at 0x7f7a2440ab70>
# 75 <__main__.Node object at 0x7f7a244111d0>
# 76 <__main__.Node object at 0x7f7a2433f048>
# 77 <__main__.Node object at 0x7f7a242bae80>
# 78 <__main__.Node object at 0x7f7a24368dd8>
# 79 <__main__.Node object at 0x7f7a241c65f8>
# 80 <__main__.Node object at 0x7f7a2419dbe0>
# 81 <__main__.Node object at 0x7f7a2418a710>
# 82 <__main__.Node object at 0x7f7a241310f0>
# 83 <__main__.Node object at 0x7f7a24325cf8>
# 84 <__main__.Node object at 0x7f7a240a4ba8>
# 85 <__main__.Node object at 0x7f7a24137da0>
# 86 <__main__.Node object at 0x7f7a24032978>
# 87 <__main__.Node object at 0x7f7a23fe5198>
# 88 <__main__.Node object at 0x7f7a23ff4208>
# 89 <__main__.Node object at 0x7f7a23f5fbe0>
# 90 <__main__.Node object at 0x7f7a23ebc6d8>
# 91 <__main__.Node object at 0x7f7a24137eb8>
# 92 <__main__.Node object at 0x7f7a23e81fd0>
# 93 <__main__.Node object at 0x7f7a23eec7b8>
# 94 <__main__.Node object at 0x7f7a23eece48>
# 95 <__main__.Node object at 0x7f7a23db6d68>
# 96 <__main__.Node object at 0x7f7a23d8e6d8>
# 97 <__main__.Node object at 0x7f7a23cffef0>
# 98 <__main__.Node object at 0x7f7a23d0c198>
# 99 <__main__.Node object at 0x7f7a23da4f28>
# 100 <__main__.Node object at 0x7f7a23d16eb8>
# 101 <__main__.Node object at 0x7f7a23c781d0>
# 102 <__main__.Node object at 0x7f7a23db6860>
# 103 <__main__.Node object at 0x7f7a23b93a20>
# 104 <__main__.Node object at 0x7f7a23afde48>
# 105 <__main__.Node object at 0x7f7a23ac3be0>
# 106 <__main__.Node object at 0x7f7a23a77f28>
# 107 <__main__.Node object at 0x7f7a23a3ba58>
# 108 <__main__.Node object at 0x7f7a23a249b0>
# 109 <__main__.Node object at 0x7f7a23a24cf8>
# 110 <__main__.Node object at 0x7f7a23a99898>
# 111 <__main__.Node object at 0x7f7a2396d240>
# 112 <__main__.Node object at 0x7f7a23913898>
# 113 <__main__.Node object at 0x7f7a23ade0f0>
# 114 <__main__.Node object at 0x7f7a23838dd8>
# 115 <__main__.Node object at 0x7f7a238e1198>
# 116 <__main__.Node object at 0x7f7a23859be0>
# 117 <__main__.Node object at 0x7f7a237a07b8>
# 118 <__main__.Node object at 0x7f7a237a0a90>
# 119 <__main__.Node object at 0x7f7a2371cba8>
# 120 <__main__.Node object at 0x7f7a23731828>
# 121 <__main__.Node object at 0x7f7a236a0080>
# 122 <__main__.Node object at 0x7f7a237a0fd0>
# 123 <__main__.Node object at 0x7f7a236061d0>
# 124 <__main__.Node object at 0x7f7a235bba20>
# 125 <__main__.Node object at 0x7f7a23538048>
# 126 <__main__.Node object at 0x7f7a235a9550>
# 127 <__main__.Node object at 0x7f7a2352eeb8>
# 128 <__main__.Node object at 0x7f7a234991d0>
# 129 <__main__.Node object at 0x7f7a235f1a58>
# 130 <__main__.Node object at 0x7f7a233c2f28>
# 131 <__main__.Node object at 0x7f7a2351bd68>
# 132 <__main__.Node object at 0x7f7a23325080>
# 133 <__main__.Node object at 0x7f7a2328ae80>
# 134 <__main__.Node object at 0x7f7a233baf98>
# 135 <__main__.Node object at 0x7f7a232085f8>
# 136 <__main__.Node object at 0x7f7a233bac88>
# 137 <__main__.Node object at 0x7f7a23155b70>
# 138 <__main__.Node object at 0x7f7a23122e10>
# 139 <__main__.Node object at 0x7f7a23109e80>
# 140 <__main__.Node object at 0x7f7a23109978>
# 141 <__main__.Node object at 0x7f7a230602b0>
# 142 <__main__.Node object at 0x7f7a22fbde48>
# 143 <__main__.Node object at 0x7f7a23052f98>
# 144 <__main__.Node object at 0x7f7a23038a90>
# 145 <__main__.Node object at 0x7f7a22f80c88>
# 146 <__main__.Node object at 0x7f7a22f9def0>
# 147 <__main__.Node object at 0x7f7a22f37f28>
# 148 <__main__.Node object at 0x7f7a22f32320>
# 149 <__main__.Node object at 0x7f7a22efcac8>
# 150 <__main__.Node object at 0x7f7a22e614a8>
# 151 <__main__.Node object at 0x7f7a22e2cf60>
# 152 <__main__.Node object at 0x7f7a22deba90>
# 153 <__main__.Node object at 0x7f7a22df46d8>
# 154 <__main__.Node object at 0x7f7a22d1ac18>
# 155 <__main__.Node object at 0x7f7a22cd3eb8>
# 156 <__main__.Node object at 0x7f7a22d06518>
# 157 <__main__.Node object at 0x7f7a22c652b0>
# 158 <__main__.Node object at 0x7f7a22ca7f28>
# 159 <__main__.Node object at 0x7f7a22cd3160>
# 160 <__main__.Node object at 0x7f7a22b8def0>
# 161 <__main__.Node object at 0x7f7a22b4df60>
# 162 <__main__.Node object at 0x7f7a22c6ca20>
# 163 <__main__.Node object at 0x7f7a22a799b0>
# 164 <__main__.Node object at 0x7f7a22a7fb38>
# 165 <__main__.Node object at 0x7f7a22a34278>
# 166 <__main__.Node object at 0x7f7a22ad1f98>
# 167 <__main__.Node object at 0x7f7a22bbfb70>
# 168 <__main__.Node object at 0x7f7a229569b0>
# 169 <__main__.Node object at 0x7f7a229dde10>
# 170 <__main__.Node object at 0x7f7a228c1e10>
# 171 <__main__.Node object at 0x7f7a22926dd8>
# 172 <__main__.Node object at 0x7f7a229dd860>
# 173 <__main__.Node object at 0x7f7a2287dda0>
# 174 <__main__.Node object at 0x7f7a22838160>
# 175 <__main__.Node object at 0x7f7a22870f98>
# 176 <__main__.Node object at 0x7f7a22806f98>
# 177 <__main__.Node object at 0x7f7a2273a0f0>
# 178 <__main__.Node object at 0x7f7a226c77f0>
# 179 <__main__.Node object at 0x7f7a2272c160>
# 180 <__main__.Node object at 0x7f7a22763780>
# 181 <__main__.Node object at 0x7f7a2256e160>

# %%
k = donk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cfd52543731e> in <module>
# ----> 1 k = donk
#
# NameError: name 'donk' is not defined

# %%
def mask2path(mask, tree):
    pathNode = -1*np.ones([mask.shape[0], len(tree.listOfLayers)+1], dtype=int)
    pathNode[:,0] = 0
    
    pathDim = -1*np.ones([mask.shape[0], len(tree.listOfLayers)+1], dtype=int)

    
    cur = 0
    for i, l in enumerate(tree.listOfLayers):
        print('layer:',i)
        
        for nIndex in l.nodeList:           
            
            n = tree.listOfNodes[nIndex]
            dim = n.w.shape[1]
            
            
            allCur = pathNode[:,i] == nIndex # in node nIndex
            sub_mask = mask[:,cur:cur+dim] # with dimenions
            ind = np.argmax(sub_mask)

            for k in range(dim):
                m = np.logical_and(allCur, sub_mask[:,k])
                pathDim[m, i] = cur + k 

            
            
            if not n.listOfChildren:
                cur = cur + dim
                continue

                        
            
            for k in range(dim):
                m = np.logical_and(allCur, sub_mask[:,k])
                pathNode[m, i+1] = n.listOfChildren[k]
                
                
            cur = cur + dim
            
            
    return pathNode, pathDim

def label2oneHot(labels):
    b = np.zeros((labels.size, labels.max()+1), dtype=bool)
    b[np.arange(labels.size),labels] = 1
    return b



def projectXX(feat, tree, maxClus=60, unit_vector=False, scale2data=False, verboise=True):
    projectionSpace = np.zeros([feat.shape[0], tree.numNodes*maxClus])
    maskAll = np.zeros([feat.shape[0], tree.numNodes*maxClus])

    cur = 0    
    for i, l in enumerate(tree.listOfLayers):
        for nIndex in l.nodeList:
            n = tree.listOfNodes[nIndex]
            f, _ = dataProjection(feat, n)
            numDim = f.shape[1]
            lab = np.argmax(f, axis =1)
            maskAll[:,cur:cur+numDim] = label2oneHot(lab)
            projectionSpace[:,cur:cur+numDim] = f
            cur = cur + numDim
    projectionSpace = projectionSpace[:,:cur]
    maskAll = maskAll[:,:cur]
    
    return projectionSpace, maskAll

# %%
pp_s = hierFeat[0]

# %%
import random
samplePerClass = 1
numClass = int(max(gt)+1)
ind = []
for i in range(numClass):
    index = list(np.where(gt==i)[0])
    if len(index) == 0:
        continue
    index = random.sample(index, samplePerClass);
    ind = ind + (index)

# %%
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

clf = LinearSVC(random_state=0, tol=1e-5)
clf.fit(pp_s[ind], gt[ind])
est = clf.predict(pp_s[1::2])

# %%
print('ours')
np.sum(est==gt[1::2])/est.size

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0, tol=1e-5)
clf.fit(feat[ind], gt[ind])
est = clf.predict(feat[1::2])
print('std')

np.sum(est==gt[1::2])/est.size

# %%
clf = LinearSVC(random_state=0, tol=1e-5)
clf.fit(kf[ind], gt[ind])
est = clf.predict(kf[1::2])
print('k-Means')

np.sum(est==gt[1::2])/est.size

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0, tol=1e-5)
clf.fit(fUmap[ind], gt[ind])
est = clf.predict(fUmap[1::2])
print('umap')
np.sum(est==gt[1::2])/est.size

# %%
from sklearn.cluster import KMeans

kMeans = KMeans(n_clusters=100).fit(feat)
kf = kMeans.transform(feat)

# %%
print('Create UMAP Feature')

! pip3 install umap.learn
import umap



f_norm, _ = normIt(feat)
embedding = umap.UMAP()
fUmap = embedding.fit_transform(f_norm)

# %% [markdown]
# ## Label Spreading evaluation

# %%
import random
from sklearn.semi_supervised import LabelSpreading
from sklearn.semi_supervised import LabelPropagation
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
# setup
lModel = LabelSpreading(gamma=100)
gt_use = gt.copy()
#gt_use = gtCoarse.copy()
#########


samplePerClass = 1000
numClass = int(max(gt_use)+1)
ind = []
for i in range(numClass):
    index = list(np.where(gt_use==i)[0])
    if len(index) == 0:
        continue
    index = random.sample(index, samplePerClass);
    ind = ind + (index)
#ind = random.sample(range(pp_s.shape[0]), numClass*samplePerClass);

# %%
print('Ours')


lModel.fit(hierFeat[0][ind], gt_use[ind])
label = lModel.predict(hierFeat[0])
score = np.max(lModel.predict_proba(hierFeat[0]), axis=1)


print('Precision:', np.sum(label==gt_use)/label.size)
print('map:', average_precision_score(label==gt_use, score))

# %%
print('Ours')


lModel.fit(hierFeat[1][ind], gt_use[ind])
label = lModel.predict(hierFeat[1])
score = np.max(lModel.predict_proba(hierFeat[1]), axis=1)


print('Precision:', np.sum(label==gt_use)/label.size)
print('map:', average_precision_score(label==gt_use, score))

# %%
from sklearn.decomposition import PCA

print('PCA')

f_norm, _ = normIt(feat)

pca = PCA(n_components=pp.shape[1])
f_pca = pca.fit_transform(f_norm)



lModel.fit(f_pca[ind], gt_use[ind])
label = lModel.predict(f_pca)
score = np.max(lModel.predict_proba(f_pca), axis=1)

print('Precision:', np.sum(label==gt_use)/label.size)
print('map:', average_precision_score(label==gt_use, score))

# %%
print('Naive')



lModel.fit(f_norm[ind], gt_use[ind])
label = lModel.predict(f_norm)
score = np.max(lModel.predict_proba(f_norm), axis=1)


print('Precision:', np.sum(label==gt_use)/label.size)
print('map:', average_precision_score(label==gt_use, score))

# %%
print('UMAP')

lModel.fit(fUmap[ind], gt_use[ind])
label = lModel.predict(fUmap)
score = np.max(lModel.predict_proba(fUmap), axis=1)

print('Precision:', np.sum(label==gt_use)/label.size)
print('map:', average_precision_score(label==gt_use, score))

# %% [markdown]
# ## Test Feature Goodness

# %%
from sklearn.metrics import pairwise_distances

def test_feat(feat, labels, nBest= 1000):
    num_feat = feat.shape[0]
    d = pairwise_distances(feat)
    ind = np.argsort(d, axis =1)
    
    err = np.zeros(num_feat)
    
    for i in range(num_feat):
        l = labels[ind[i,:nBest+1]]      
        err[i] = nBest - (sum((l-l[0]) == 0))+1
                          
    return err



nBest = 100

ff = hierFeat[0]

err = test_feat(ff, gt, nBest=nBest)
print('average error of  %f from %d nearest neighbors'  %(np.mean(err), nBest))

print('num dimenions:', ff.shape[1])
# Out:
# average error of  8.148769 from 100 nearest neighbors
# num dimenions: 364

# %%
err = test_feat(kf, gt, nBest=nBest)
print('average error of  %f from %d nearest neighbors'  %(np.mean(err), nBest))

print('num dimenions:', kf.shape[1])

# %%
ff = hierFeat[1]

err = test_feat(ff, gt, nBest=nBest)
print('average error of  %f from %d nearest neighbors'  %(np.mean(err), nBest))

print('num dimenions:', ff.shape[1])

# %%
ff = hierFeat[2]

err = test_feat(ff, gt, nBest=nBest)
print('average error of  %f from %d nearest neighbors'  %(np.mean(err), nBest))

print('num dimenions:', ff.shape[1])

# %%
from sklearn.decomposition import PCA

f_norm, m_ = normIt(feat)

pca = PCA(pp_s.shape[1])
pca.fit(f_norm)
f_pca = pca.transform(f_norm)

err = test_feat(f_pca, gt, nBest=nBest)
print('average error of  %f from %d nearest neighbors'  %(np.mean(err), nBest))

print('num dimenions:', f_pca.shape[1])

# %%
# !pip3 install -U sklearn

# %%
from sklearn.neighbors import NearestNeighbors
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(f_norm)
distances, indices = nbrs.kneighbors(f_norm)

# %%
est = np.zeros(gtAll.size, dtype=int)
for i in indices[:,1]:
    est[i] = gtAll[i]
1-np.sum((est==gtAll))/est.size

# %%
f_norm, m_ = normIt(feat)


err = test_feat(f_norm, gtAll, nBest=nBest)
print('average error of  %f from %d nearest neighbors'  %(np.mean(err), nBest))

print('num dimenions:', f_norm.shape[1])

# %%
from sklearn.neighbors import NearestNeighbors
#distances, indices = nbrs.kneighbors(f_norm)

# %%
i = 0
nbrs = NearestNeighbors(n_neighbors=1000, algorithm='ball_tree').fit(pp_s2)
distances, indices = nbrs.kneighbors(pp_s2[i:i+1,:])
print(np.sum(indices<1300))

# %%
nbrs = NearestNeighbors(n_neighbors=1000, algorithm='ball_tree').fit(f_norm)
distances, indices = nbrs.kneighbors(f_norm[i:i+1,:])
print(np.sum(indices<1300))
