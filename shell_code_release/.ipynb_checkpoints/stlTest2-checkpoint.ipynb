# %%
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras import backend as K
import numpy as np

import dirUtil 
from highDimLearning import vgg2feat

import tensorflow as tf

from sklearn.metrics.pairwise import euclidean_distances

import matplotlib.pyplot as plt


import os
import random 
    

def feat2labels(feat):
    numClass = len(feat)
    numDim = feat[0].shape[1]
    numPts = 0
    for i in range(numClass):
        numPts = numPts + feat[i].shape[0]

    allFeat = np.zeros([numPts, numDim])
    allLabels = np.zeros(numPts, dtype = int)
    cur = 0
    for i in range(numClass):
        allFeat[cur:cur+feat[i].shape[0],:] = feat[i]
        allLabels[cur:cur+feat[i].shape[0]] = i
        cur = cur + feat[i].shape[0]
    return allFeat, allLabels
        
    
def readNetVlad(folder, numDim =4096):
    folderName = os.path.basename(os.path.normpath(folder))
    print(folderName)
    file = folder +'/vd16_pitts30k_conv5_3_vlad_preL2_intra_white_' +folderName + '_db.bin'    
    data = np.fromfile(file, '<f4')
    numPts = int(len(data)/numDim)
    return np.reshape(data, [numPts, numDim])

from scipy.optimize import linear_sum_assignment

def cluster_acc(Y_pred, Y):
    assert Y_pred.size == Y.size
    D = max(Y_pred.max(), Y.max())+1
    w = np.zeros((D,D), dtype=np.int64)
    for i in range(Y_pred.size):
        w[Y_pred[i], Y[i]] += 1
    
    row_ind, col_ind = linear_sum_assignment(w.max() - w)
    
    print(w[row_ind,col_ind])
    return w[row_ind,col_ind].sum()/Y_pred.size, w



feat = np.load('/media/daniel/D/Data/STL-10/feats_2048.npy')
gt = np.load('/media/daniel/D/Data/STL-10/labels_2048.npy')-1

mask = gt>-1#np.logical_or(gt==3, gt==4)
feat = feat[mask,:]
gt = gt[mask]
# Out:
# Using TensorFlow backend.

# %%
feat1 = readNetVlad('/media/daniel/D/Data/basicMITData/abbey')
    
feat2 = readNetVlad('/media/daniel/D/Data/basicMITData/airport_terminal')

feat3 = readNetVlad('/media/daniel/D/Data/basicMITData/alley')

feat4 = readNetVlad('/media/daniel/D/Data/basicMITData/amphitheater')

feat, gt = feat2labels([feat1, feat2, feat3, feat4])
# Out:
# abbey
# airport_terminal
# alley
# amphitheater

# %%
from keras.datasets import mnist
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

feat = np.reshape(x_test, [x_test.shape[0], x_test.shape[1]*x_test.shape[2]])

# from sklearn.decomposition import PCA
# pca = PCA(n_components=0.9)
# pca.fit(feat)
# feat = pca.transform(feat)


gt = y_test

mask = gt<4
feat = feat[mask, :]
gt = gt[mask]

# %%
print(feat.shape)
# Out:
# (4157, 42)

# %%
# %load_ext autoreload
# %autoreload


from cluster_eval import eval_ours

purity, map_, our_labels, para = eval_ours(feat, 2, gt, add_dim_per_class=5)
print(purity, map_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1058.7681
# 0.002951658
# 0.009999264
# 0.0003361802
# 0.003993158
# 0.00043162066
# 0.0019695559
# 0.0061585973
# 0.00907476
# 0.008773909
# 0.011891036
# 27.881453
# 0.0025767607
# 0.0018622533
# 0.0014508314
# 0.0012650774
# 0.0011711796
# 0.002731081
# 0.00022122127
# 0.0005998809
# 0.00016178985
# 0.00793574
# 0.006236284
# 0.0057972055
# 0.0055621807
# 0.005394364
# 0.0052635144
# 0.005156561
# 0.0050666947
# 0.004989662
# 0.0049226647
# 0.0048637725
# 0.004811545
# 0.004764741
# 0.004722803
# 0.0046847835
# 0.0046504154
# 0.004619096
# 0.004590299
# 0.0045640524
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-28-efbd017ce5ed> in <module>
#       5 from cluster_eval import eval_ours
#       6
# ...

# %%
from clusteringXXX import cluster_data
w, sig, labelK = cluster_data(
        feat1, numClass=2, add_dim_per_class=5)
# Out:
# 678.98236
# 4.345176e-05
# 0.0002087111
# 0.0005871734
# 0.0044650007
# 0.00037058667
# 0.0017335112
# 0.009042721
# 0.01100739
# 1737.1918
# 0.0039820103
# 0.0009871802
# 0.00062514265
# 0.00042490687
# 0.00029645555
# 0.00020915139
# 0.00075922435
# 0.00013024012
# 8.812648e-05
# 7.866739e-05
# 1.545048e-05
# 1.4974435e-05
# 1.4578559e-05
# 1.4346296e-05
# 1.413843e-05
# 1.3943854e-05
# 1.3935145e-05
# 1.3751217e-05
# 1.3449801e-05
# 1.3447188e-05
# 1.3266063e-05
# 1.3144611e-05
# 1.3142306e-05
# 1.2901506e-05
# 1.2779878e-05
# 1.2658206e-05
# 1.2596118e-05
# 1.2593649e-05
# 1.2412413e-05
# 1.2231231e-05

# %%
from sklearn.svm import OneClassSVM



clf = OneClassSVM(gamma='auto').fit(feat[gt==0])

# %%
scores = clf.score_samples(feat)

# %%
ind = np.argsort(-scores)
ind = ind[:1000]
np.sum(ind)

# %%
# Out:
# 341

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.9)
pca.fit(feat)
feat = pca.transform(feat1)

# %%
from keras.preprocessing import image
import os
import shutil 


def printMnist(data, folder):
    
    if os.path.isdir(folder):
        shutil.rmtree(folder)
        os.mkdir(folder)
    else:
        os.mkdir(folder)

    
    for i in range(data.shape[0]):
        f = data[i,:]
        f = np.reshape(f, [28,28])
        f = np.repeat(f[:, :, np.newaxis], 3, axis=2)
        image.save_img(folder + '/' + str(i).zfill(6) + '.jpg', f)


mask = np.where(our_labels ==3)[0]
score = np.max(hyper_feat[mask,:], axis =1)
mask = mask[np.argsort(-score)]

printMnist(feat[mask,:], '/media/daniel/D/Data/tmp/mnist1/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-db48c5d3b492> in <module>
#      25 mask = mask[np.argsort(-score)]
#      26
# ---> 27 printMnist(feat[mask,:], '/media/daniel/D/Data/tmp/mnist1/')
#
# <ipython-input-21-db48c5d3b492> in printMnist(data, folder)
#      16     for i in range(data.shape[0]):
#      17         f = data[i,:]
# ---> 18         f = np.reshape(f, [28,28])
#      19         f = np.repeat(f[:, :, np.newaxis], 3, axis=2)
#      20         image.save_img(folder + '/' + str(i).zfill(6) + '.jpg', f)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     290            [5, 6]])
#     291     """
# --> 292     return _wrapfunc(a, 'reshape', newshape, order=order)
#     293
#     294
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
# ...

# %%
print(np.max(our_labels))
# Out:
# 3

# %%
from clusteringXXX import cluster_project
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

[w, sig, mask] = para

ww = w[:,mask]

scaler = StandardScaler(copy=True, with_mean=True,
                            with_std=False).fit(feat)
new_feat = scaler.transform(feat, copy=True)
new_feat = new_feat/np.linalg.norm(new_feat, keepdims=True, axis=1)

hyper_label, hyper_feat = cluster_project(new_feat, ww, sig, ww.shape[1])

print(hyper_feat.shape)

c = hyper_feat/np.linalg.norm(hyper_feat, keepdims=True, axis=1)


plt.scatter(c[:,3], c[:,2], c= gt, alpha=0.1)
# Out:
# (4157, 4)

# %%
purity, map_, label_k, _ = eval_kmeans(c, 2, gt)
print(purity, map_)
# Out:
# 0.9655306047753354 0.9793172444797585

# %%
# %load_ext autoreload
# %autoreload

from cluster_eval import eval_kmeans

purity, map_, label_k, _ = eval_kmeans(feat, 4, gt)
print(purity, map_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.8948761125811884 0.9844302105649647
